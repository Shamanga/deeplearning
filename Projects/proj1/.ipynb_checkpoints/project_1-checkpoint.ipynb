# %%
import torch
import torchvision
import warnings
import torch.nn as nn
from PIL import Image
import statistics as st
from utils.utils import *
import torch.optim as optim
from torch.utils import data
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data.dataset import Dataset
from timeit import default_timer as timer
from nets.NN1 import NN1
from nets.NN2 import NN2
from nets.train_test import * 
from utils.MnistPairs import MnistPairs
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

#### Parameters ####
n_epochs = 25
iters = 1
batch_size_train = 64
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 10
random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)
#### Parameters ####

def main():
    """
    The function 
    - loads the train and test dataset according to given batchsizes 
    - trains and tests the first network
    - trains and tests the second network
    """
    #Loading dataset
    trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
    
    train_dataset = MnistPairs('data/',train=True, transform=None)
    test_dataset = MnistPairs('data/',train=False, transform=None)
    

    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                               batch_size=batch_size_train, 
                                               shuffle=True)

    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                              batch_size=batch_size_test, 
                                              shuffle=True)
    
    print("\n Start of the Network 2 ")
    network2 = NN2()
    optimizer2 = optim.SGD(network2.parameters(), lr=learning_rate, momentum=momentum)
    
    print("The number of parameters of the network is ", count_parameters(network2))
    
    
    train_loss__ = []
    train_acc_digits__ = []
    train_acc_classes__ = []
    
    train_loss_ = []
    train_acc_digits_ = []
    train_acc_classes_= []

    test_loss__ = []
    test_acc_digits__ = []
    test_acc_classes__ = []
    avg_time2 = 0
    for i in range(iters):
        for epoch in range(1, n_epochs + 1):
            start = timer()
            train_loss, train_acc_digits, train_acc_classes  = train2(epoch, network2,train_loader,optimizer2) 
            end = timer()
            print("Time needed to train ", end - start)
            avg_time2 += end - start
            test_loss, test_acc_digits, test_acc_classes = test2(network2, test_loader)
            
            train_loss__ += train_loss
            train_acc_digits__ += train_acc_digits
            train_acc_classes__ += train_acc_classes
            
            train_loss_.append(mean(train_loss))
            train_acc_digits_.append(mean(train_acc_digits))
            train_acc_classes_.append(mean(train_acc_classes))
            
            test_loss__.append(test_loss)
            test_acc_digits__.append(test_acc_digits)
            test_acc_classes__.append(test_acc_classes)
            
    avg_time2 /=(iters * n_epochs)
    plt.figure()
    plt.plot(train_loss__, label = "train_loss__") 
    plt.ylabel("Negative log likelihood loss")
    plt.xlabel("Iterations")
    plt.title("Network 2 Classification Loss ")
    plt.show()
    
    plt.figure()
    plt.plot(train_acc_digits__, label = "train_acc_digits")
    plt.plot(train_acc_classes__, label = "train_acc_classes") 
    plt.legend()
    plt.ylabel("Accuracy")
    plt.xlabel("Iterations")
    plt.title("Network 2 Classification Accuracy ")
    plt.show()
    
    plt.figure()
    plt.plot(test_loss__, label = "test_loss") 
    plt.plot(train_loss_, label = "train_loss")
    plt.legend()
    plt.ylabel("Negative log likelihood loss")
    plt.xlabel("Number of seen testing data")
    plt.title("Network 2 Classification Loss ")
    plt.show()
    
    plt.figure()
    plt.plot(test_acc_digits__, label = "test_acc_digits")
    plt.plot(test_acc_classes__, label = "test_acc_classes")
    plt.plot(train_acc_digits_, label = "train_acc_digits")
    plt.plot(train_acc_classes_, label = "train_acc_classes")
    plt.legend()
    plt.ylabel("Accuracy")
    plt.xlabel("Number of seen data")
    plt.title("Network 2 Classification Accuracy")
    plt.show()
                      
    
    
    
   
    print("*************************** Start of the Network 1 ***************************")
    network1 = NN1()
    optimizer1 = optim.SGD(network1.parameters(), lr=learning_rate, momentum=momentum)
    
    train_loss__ = []
    train_acc__ = []
    
    train_loss_ = []
    train_acc_ = []

    test_loss__ = []
    test_acc__ = []
    avg_time1 = 0
    
    print("\n The number of parameters of the network is \n ", count_parameters(network1))
    for i in range(iters):
        t_loss = []
        t_acc = []
        test_loss_ = []
        test_acc_ = []
        for epoch in range(1, n_epochs + 1):
            start = timer()
            train_loss, train_acc  = train1(epoch, network1, train_loader, optimizer1) 
            end = timer()
            print("\n Time needed to train ", end - start)
            avg_time1 += end - start
            
            test_loss, test_acc = test1(network1, test_loader)
            
            train_loss__ += train_loss
            train_acc__ += train_acc_
            
            train_loss_.append(mean(train_loss))
            train_acc_.append(mean(train_acc))
            
            test_loss__.append(test_loss)
            test_acc__.append(test_acc)
            
    avg_time1 /= (iters * n_epochs)
    plt.figure()
    plt.plot(train_loss__, label = "train_loss__") 
    plt.ylabel("Cross Entropy loss")
    plt.legend()
    plt.xlabel("Iterations")
    plt.title("Network 1 Classification Loss ")
    plt.show()
    
    
    plt.figure()
    plt.plot(test_loss__, label = "test_loss") 
    plt.plot(train_loss_, label = "train_loss")
    plt.legend()
    plt.ylabel("Cross Entropy loss")
    plt.xlabel("Iterations")
    plt.title("Network 1 Classification Loss ")
    plt.show()
    
    plt.figure()
    plt.plot(test_acc_digits__, label = "test_acc_digits")
    plt.plot(test_acc_classes__, label = "test_acc_classes")
    plt.plot(train_acc_digits_, label = "train_acc_digits")
    plt.plot(train_acc_classes_, label = "train_acc_classes")
    plt.legend()
    plt.ylabel("Accuracy")
    plt.xlabel("Iterations")
    plt.title("Network 1 Classification Accuracy")
    plt.show()
    
    return avg_time2, train_acc_classes__, train_acc_digits__ , test_acc_classes__, test_acc_digits__, avg_time1, train_acc__, test_acc__
      
        
        
       
if __name__ == '__main__':
    avg_time2, train_acc_classes__, train_acc_digits__ , test_acc_classes__, test_acc_digits__, avg_time1, train_acc__, test_acc__ = main()
    print(" \n ************************ Statistics of Network 2 ************************ \n")
    print("\n Average time needed for training: ", avg_time2)
    print("\n Training: ","\n Average accuracy of labels: {}".format(st.mean(train_acc_classes__)),"\n Median accuracy of labels: {}".format(st.median(train_acc_classes__)),"\n Average accuracy on labels: {}".format(st.mean(train_acc_classes__)),"\n Maximum accuracy on labels: {}".format(max(train_acc_classes__)),"\n Minimum accuracy on labels: {}".format(min(train_acc_classes__)),"\n Spread of accuracy on labels: {}".format(st.stdev(train_acc_classes__)),"\n Average accuracy of digits: {}".format(st.mean(train_acc_digits__)),"\n Median accuracy of digits: {}".format(st.median(train_acc_digits__)),"\n Average accuracy on digits: {}".format(st.mean(train_acc_digits__)),"\n Maximum accuracy on digits: {}".format(max(train_acc_digits__)),"\n Minimum accuracy on digits: {}".format(min(train_acc_digits__)),"\n Spread of accuracy on digits: {}".format(st.stdev(train_acc_digits__)))
    print("\n Testing: ","\n Average accuracy of labels: {}".format(st.mean(test_acc_classes__)),"\n Median accuracy of labels: {}".format(st.median(test_acc_classes__)),"\n Average accuracy on labels: {}".format(st.mean(test_acc_classes__)),"\n Maximum accuracy on labels: {}".format(max(test_acc_classes__)),"\n Minimum accuracy on labels: {}".format(min(test_acc_classes__)),"\n Spread of accuracy on labels: {}".format(st.stdev(test_acc_classes__)),"\n Average accuracy of digits: {}".format(st.mean(test_acc_digits__)),"\n Median accuracy of digits: {}".format(st.median(test_acc_digits__)),"\n Average accuracy on digits: {}".format(st.mean(test_acc_digits__)),"\n Maximum accuracy on digits: {}".format(max(test_acc_digits__)),"\n Minimum accuracy on digits: {}".format(min(test_acc_digits__)),"\n Spread of accuracy on digits: {}".format(st.stdev(test_acc_digits__)))
    
    
    print("\n ************************ Statistics of Network 1 ************************ \n")
    print("\n Average time needed for training ", avg_time1)
    print("\n Training: ", "\n Average accuracy of labels: {}".format(st.mean(train_acc__)),"\n Median accuracy of labels: {}".format(st.median(train_acc__)),"\n Average accuracy on labels: {}".format(st.mean(train_acc__)),"\n Maximum accuracy on labels: {}".format(max(train_acc__)),"\n Minimum accuracy on labels: {}".format(min(train_acc__)),"\n Spread of accuracy on labels: {}".format(st.stdev(train_acc__)))
    print("\n Testing: ", "\n Average accuracy of labels: {}".format(st.mean(test_acc__)),"\n Median accuracy of labels: {}".format(st.median(test_acc__)), "\n Average accuracy on labels: {}".format(st.mean(test_acc__)),"\n Maximum accuracy on labels: {}".format(max(test_acc__)), "\n Minimum accuracy on labels: {}".format(min(test_acc__)), "\n Spread of accuracy on labels: {}".format(st.stdev(test_acc__)))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
#  Start of the Network 2
# The number of parameters of the network is  8862
# Epoch [2/25],Step [1/64],Loss: 15.8453, Acc_digits: 12/128 (9%) ,Acc_labels: 32/64 (50%)
# Epoch [2/25],Step [2/64],Loss: 6.0161, Acc_digits: 10/128 (8%) ,Acc_labels: 34/64 (53%)
# Epoch [2/25],Step [3/64],Loss: 3.6222, Acc_digits: 13/128 (10%) ,Acc_labels: 31/64 (48%)
# Epoch [2/25],Step [4/64],Loss: 3.1423, Acc_digits: 11/128 (9%) ,Acc_labels: 34/64 (53%)
# Epoch [2/25],Step [5/64],Loss: 3.0845, Acc_digits: 18/128 (14%) ,Acc_labels: 31/64 (48%)
# Epoch [2/25],Step [6/64],Loss: 3.0063, Acc_digits: 17/128 (13%) ,Acc_labels: 34/64 (53%)
# Epoch [2/25],Step [7/64],Loss: 3.0503, Acc_digits: 15/128 (12%) ,Acc_labels: 29/64 (45%)
# Epoch [2/25],Step [8/64],Loss: 2.9512, Acc_digits: 21/128 (16%) ,Acc_labels: 38/64 (59%)
# Epoch [2/25],Step [9/64],Loss: 2.9756, Acc_digits: 19/128 (15%) ,Acc_labels: 36/64 (56%)
# Epoch [2/25],Step [10/64],Loss: 2.9502, Acc_digits: 18/128 (14%) ,Acc_labels: 34/64 (53%)
# Epoch [2/25],Step [11/64],Loss: 3.0059, Acc_digits: 17/128 (13%) ,Acc_labels: 30/64 (47%)
# Epoch [2/25],Step [12/64],Loss: 2.9656, Acc_digits: 21/128 (16%) ,Acc_labels: 36/64 (56%)
# Epoch [2/25],Step [13/64],Loss: 2.9375, Acc_digits: 22/128 (17%) ,Acc_labels: 34/64 (53%)
# Epoch [2/25],Step [14/64],Loss: 2.9204, Acc_digits: 24/128 (19%) ,Acc_labels: 33/64 (52%)
# Epoch [2/25],Step [15/64],Loss: 2.9006, Acc_digits: 20/128 (16%) ,Acc_labels: 32/64 (50%)
# Epoch [2/25],Step [16/40],Loss: 3.0189, Acc_digits: 10/80 (12%) ,Acc_labels: 18/40 (45%)
# Time needed to train  0.25627025100402534
#
# Test set: Loss: 2.9094,Acc_digits: 528/2000 (26%),Acc_labels: 561/1000 56%
# Epoch [3/25],Step [1/64],Loss: 2.9316, Acc_digits: 18/128 (14%) ,Acc_labels: 30/64 (47%)
# Epoch [3/25],Step [2/64],Loss: 2.9556, Acc_digits: 19/128 (15%) ,Acc_labels: 32/64 (50%)
# Epoch [3/25],Step [3/64],Loss: 2.9462, Acc_digits: 20/128 (16%) ,Acc_labels: 34/64 (53%)
# Epoch [3/25],Step [4/64],Loss: 2.9443, Acc_digits: 20/128 (16%) ,Acc_labels: 32/64 (50%)
# Epoch [3/25],Step [5/64],Loss: 2.9145, Acc_digits: 26/128 (20%) ,Acc_labels: 31/64 (48%)
# Epoch [3/25],Step [6/64],Loss: 2.8994, Acc_digits: 24/128 (19%) ,Acc_labels: 36/64 (56%)
# Epoch [3/25],Step [7/64],Loss: 2.8959, Acc_digits: 22/128 (17%) ,Acc_labels: 34/64 (53%)
# Epoch [3/25],Step [8/64],Loss: 2.9222, Acc_digits: 25/128 (20%) ,Acc_labels: 29/64 (45%)
# Epoch [3/25],Step [9/64],Loss: 2.9321, Acc_digits: 26/128 (20%) ,Acc_labels: 36/64 (56%)
# Epoch [3/25],Step [10/64],Loss: 2.9000, Acc_digits: 22/128 (17%) ,Acc_labels: 28/64 (44%)
# Epoch [3/25],Step [11/64],Loss: 2.8821, Acc_digits: 23/128 (18%) ,Acc_labels: 35/64 (55%)
# Epoch [3/25],Step [12/64],Loss: 2.8818, Acc_digits: 18/128 (14%) ,Acc_labels: 36/64 (56%)
# Epoch [3/25],Step [13/64],Loss: 2.8910, Acc_digits: 19/128 (15%) ,Acc_labels: 38/64 (59%)
# Epoch [3/25],Step [14/64],Loss: 2.8506, Acc_digits: 21/128 (16%) ,Acc_labels: 30/64 (47%)
# Epoch [3/25],Step [15/64],Loss: 2.8067, Acc_digits: 27/128 (21%) ,Acc_labels: 39/64 (61%)
# Epoch [3/25],Step [16/40],Loss: 2.8946, Acc_digits: 11/80 (14%) ,Acc_labels: 22/40 (55%)
# Time needed to train  0.2445931009715423
#
# Test set: Loss: 2.7882,Acc_digits: 596/2000 (30%),Acc_labels: 581/1000 58%
# Epoch [4/25],Step [1/64],Loss: 2.8160, Acc_digits: 32/128 (25%) ,Acc_labels: 32/64 (50%)
# Epoch [4/25],Step [2/64],Loss: 2.7620, Acc_digits: 38/128 (30%) ,Acc_labels: 31/64 (48%)
# Epoch [4/25],Step [3/64],Loss: 2.7845, Acc_digits: 28/128 (22%) ,Acc_labels: 38/64 (59%)
# Epoch [4/25],Step [4/64],Loss: 2.8042, Acc_digits: 31/128 (24%) ,Acc_labels: 35/64 (55%)
# Epoch [4/25],Step [5/64],Loss: 2.7822, Acc_digits: 27/128 (21%) ,Acc_labels: 37/64 (58%)
# Epoch [4/25],Step [6/64],Loss: 2.8167, Acc_digits: 32/128 (25%) ,Acc_labels: 40/64 (62%)
# Epoch [4/25],Step [7/64],Loss: 2.8854, Acc_digits: 24/128 (19%) ,Acc_labels: 36/64 (56%)
# Epoch [4/25],Step [8/64],Loss: 2.9570, Acc_digits: 15/128 (12%) ,Acc_labels: 31/64 (48%)
# Epoch [4/25],Step [9/64],Loss: 2.8162, Acc_digits: 28/128 (22%) ,Acc_labels: 35/64 (55%)
# Epoch [4/25],Step [10/64],Loss: 2.8163, Acc_digits: 24/128 (19%) ,Acc_labels: 40/64 (62%)
# Epoch [4/25],Step [11/64],Loss: 2.7446, Acc_digits: 34/128 (27%) ,Acc_labels: 35/64 (55%)
# Epoch [4/25],Step [12/64],Loss: 2.7722, Acc_digits: 27/128 (21%) ,Acc_labels: 31/64 (48%)
# Epoch [4/25],Step [13/64],Loss: 2.7055, Acc_digits: 32/128 (25%) ,Acc_labels: 38/64 (59%)
# Epoch [4/25],Step [14/64],Loss: 2.7661, Acc_digits: 28/128 (22%) ,Acc_labels: 35/64 (55%)
# Epoch [4/25],Step [15/64],Loss: 2.6636, Acc_digits: 33/128 (26%) ,Acc_labels: 38/64 (59%)
# Epoch [4/25],Step [16/40],Loss: 2.9800, Acc_digits: 7/80 (9%) ,Acc_labels: 19/40 (48%)
# Time needed to train  0.2308756218990311
#
# Test set: Loss: 2.6928,Acc_digits: 656/2000 (33%),Acc_labels: 586/1000 59%
# Epoch [5/25],Step [1/64],Loss: 2.7568, Acc_digits: 38/128 (30%) ,Acc_labels: 35/64 (55%)
# Epoch [5/25],Step [2/64],Loss: 2.7662, Acc_digits: 35/128 (27%) ,Acc_labels: 29/64 (45%)
# Epoch [5/25],Step [3/64],Loss: 2.7551, Acc_digits: 26/128 (20%) ,Acc_labels: 37/64 (58%)
# Epoch [5/25],Step [4/64],Loss: 2.7472, Acc_digits: 35/128 (27%) ,Acc_labels: 34/64 (53%)
# Epoch [5/25],Step [5/64],Loss: 2.7431, Acc_digits: 32/128 (25%) ,Acc_labels: 37/64 (58%)
# Epoch [5/25],Step [6/64],Loss: 2.7582, Acc_digits: 33/128 (26%) ,Acc_labels: 33/64 (52%)
# Epoch [5/25],Step [7/64],Loss: 2.8076, Acc_digits: 35/128 (27%) ,Acc_labels: 35/64 (55%)
# Epoch [5/25],Step [8/64],Loss: 2.7886, Acc_digits: 31/128 (24%) ,Acc_labels: 36/64 (56%)
# Epoch [5/25],Step [9/64],Loss: 2.7396, Acc_digits: 30/128 (23%) ,Acc_labels: 41/64 (64%)
# Epoch [5/25],Step [10/64],Loss: 2.6700, Acc_digits: 35/128 (27%) ,Acc_labels: 38/64 (59%)
# Epoch [5/25],Step [11/64],Loss: 2.7813, Acc_digits: 33/128 (26%) ,Acc_labels: 34/64 (53%)
# Epoch [5/25],Step [12/64],Loss: 2.6981, Acc_digits: 37/128 (29%) ,Acc_labels: 43/64 (67%)
# Epoch [5/25],Step [13/64],Loss: 2.7976, Acc_digits: 26/128 (20%) ,Acc_labels: 36/64 (56%)
# Epoch [5/25],Step [14/64],Loss: 2.6108, Acc_digits: 38/128 (30%) ,Acc_labels: 37/64 (58%)
# Epoch [5/25],Step [15/64],Loss: 2.6422, Acc_digits: 34/128 (27%) ,Acc_labels: 33/64 (52%)
# Epoch [5/25],Step [16/40],Loss: 2.8449, Acc_digits: 20/80 (25%) ,Acc_labels: 23/40 (57%)
# Time needed to train  0.26601017999928445
#
# Test set: Loss: 2.5677,Acc_digits: 726/2000 (36%),Acc_labels: 602/1000 60%
# Epoch [6/25],Step [1/64],Loss: 2.6492, Acc_digits: 34/128 (27%) ,Acc_labels: 30/64 (47%)
# Epoch [6/25],Step [2/64],Loss: 2.7679, Acc_digits: 23/128 (18%) ,Acc_labels: 36/64 (56%)
# Epoch [6/25],Step [3/64],Loss: 2.6423, Acc_digits: 34/128 (27%) ,Acc_labels: 32/64 (50%)
# Epoch [6/25],Step [4/64],Loss: 2.5976, Acc_digits: 41/128 (32%) ,Acc_labels: 33/64 (52%)
# Epoch [6/25],Step [5/64],Loss: 2.6220, Acc_digits: 37/128 (29%) ,Acc_labels: 36/64 (56%)
# Epoch [6/25],Step [6/64],Loss: 2.6777, Acc_digits: 35/128 (27%) ,Acc_labels: 41/64 (64%)
# Epoch [6/25],Step [7/64],Loss: 2.7326, Acc_digits: 31/128 (24%) ,Acc_labels: 39/64 (61%)
# Epoch [6/25],Step [8/64],Loss: 2.7205, Acc_digits: 33/128 (26%) ,Acc_labels: 42/64 (66%)
# Epoch [6/25],Step [9/64],Loss: 2.6189, Acc_digits: 33/128 (26%) ,Acc_labels: 44/64 (69%)
# Epoch [6/25],Step [10/64],Loss: 2.6022, Acc_digits: 41/128 (32%) ,Acc_labels: 38/64 (59%)
# Epoch [6/25],Step [11/64],Loss: 2.6724, Acc_digits: 32/128 (25%) ,Acc_labels: 31/64 (48%)
# Epoch [6/25],Step [12/64],Loss: 2.4858, Acc_digits: 53/128 (41%) ,Acc_labels: 44/64 (69%)
# Epoch [6/25],Step [13/64],Loss: 2.7330, Acc_digits: 35/128 (27%) ,Acc_labels: 34/64 (53%)
# Epoch [6/25],Step [14/64],Loss: 2.6533, Acc_digits: 42/128 (33%) ,Acc_labels: 34/64 (53%)
# Epoch [6/25],Step [15/64],Loss: 2.6657, Acc_digits: 39/128 (30%) ,Acc_labels: 34/64 (53%)
# Epoch [6/25],Step [16/40],Loss: 2.5521, Acc_digits: 26/80 (32%) ,Acc_labels: 18/40 (45%)
# Time needed to train  0.23979079304262996
#
# Test set: Loss: 2.5194,Acc_digits: 843/2000 (42%),Acc_labels: 603/1000 60%
# Epoch [7/25],Step [1/64],Loss: 2.6068, Acc_digits: 38/128 (30%) ,Acc_labels: 37/64 (58%)
# Epoch [7/25],Step [2/64],Loss: 2.6992, Acc_digits: 35/128 (27%) ,Acc_labels: 31/64 (48%)
# Epoch [7/25],Step [3/64],Loss: 2.7235, Acc_digits: 30/128 (23%) ,Acc_labels: 40/64 (62%)
# Epoch [7/25],Step [4/64],Loss: 2.5829, Acc_digits: 40/128 (31%) ,Acc_labels: 38/64 (59%)
# Epoch [7/25],Step [5/64],Loss: 2.6719, Acc_digits: 36/128 (28%) ,Acc_labels: 32/64 (50%)
# Epoch [7/25],Step [6/64],Loss: 2.4371, Acc_digits: 52/128 (41%) ,Acc_labels: 42/64 (66%)
# Epoch [7/25],Step [7/64],Loss: 2.6590, Acc_digits: 40/128 (31%) ,Acc_labels: 33/64 (52%)
# Epoch [7/25],Step [8/64],Loss: 2.5335, Acc_digits: 47/128 (37%) ,Acc_labels: 39/64 (61%)
# Epoch [7/25],Step [9/64],Loss: 2.7469, Acc_digits: 35/128 (27%) ,Acc_labels: 43/64 (67%)
# Epoch [7/25],Step [10/64],Loss: 2.5658, Acc_digits: 45/128 (35%) ,Acc_labels: 38/64 (59%)
# Epoch [7/25],Step [11/64],Loss: 2.7614, Acc_digits: 30/128 (23%) ,Acc_labels: 45/64 (70%)
# Epoch [7/25],Step [12/64],Loss: 2.6279, Acc_digits: 40/128 (31%) ,Acc_labels: 41/64 (64%)
# Epoch [7/25],Step [13/64],Loss: 2.6404, Acc_digits: 41/128 (32%) ,Acc_labels: 42/64 (66%)
# Epoch [7/25],Step [14/64],Loss: 2.5822, Acc_digits: 41/128 (32%) ,Acc_labels: 38/64 (59%)
# Epoch [7/25],Step [15/64],Loss: 2.7250, Acc_digits: 36/128 (28%) ,Acc_labels: 32/64 (50%)
# Epoch [7/25],Step [16/40],Loss: 2.5298, Acc_digits: 26/80 (32%) ,Acc_labels: 24/40 (60%)
# Time needed to train  0.24408676207531244
# Test set: Loss: 2.4564,Acc_digits: 860/2000 (43%),Acc_labels: 597/1000 60%
# Epoch [8/25],Step [1/64],Loss: 2.6101, Acc_digits: 38/128 (30%) ,Acc_labels: 38/64 (59%)
# Epoch [8/25],Step [2/64],Loss: 2.6257, Acc_digits: 34/128 (27%) ,Acc_labels: 34/64 (53%)
# Epoch [8/25],Step [3/64],Loss: 2.5267, Acc_digits: 43/128 (34%) ,Acc_labels: 43/64 (67%)
# Epoch [8/25],Step [4/64],Loss: 2.5945, Acc_digits: 35/128 (27%) ,Acc_labels: 44/64 (69%)
# Epoch [8/25],Step [5/64],Loss: 2.5733, Acc_digits: 49/128 (38%) ,Acc_labels: 37/64 (58%)
# Epoch [8/25],Step [6/64],Loss: 2.5122, Acc_digits: 44/128 (34%) ,Acc_labels: 37/64 (58%)
# Epoch [8/25],Step [7/64],Loss: 2.6605, Acc_digits: 36/128 (28%) ,Acc_labels: 32/64 (50%)
# Epoch [8/25],Step [8/64],Loss: 2.6101, Acc_digits: 39/128 (30%) ,Acc_labels: 31/64 (48%)
# Epoch [8/25],Step [9/64],Loss: 2.5189, Acc_digits: 38/128 (30%) ,Acc_labels: 33/64 (52%)
# Epoch [8/25],Step [10/64],Loss: 2.6043, Acc_digits: 37/128 (29%) ,Acc_labels: 43/64 (67%)
# Epoch [8/25],Step [11/64],Loss: 2.4838, Acc_digits: 47/128 (37%) ,Acc_labels: 40/64 (62%)
# Epoch [8/25],Step [12/64],Loss: 2.5000, Acc_digits: 48/128 (38%) ,Acc_labels: 40/64 (62%)
# Epoch [8/25],Step [13/64],Loss: 2.4616, Acc_digits: 45/128 (35%) ,Acc_labels: 45/64 (70%)
# Epoch [8/25],Step [14/64],Loss: 2.5709, Acc_digits: 44/128 (34%) ,Acc_labels: 38/64 (59%)
# Epoch [8/25],Step [15/64],Loss: 2.5893, Acc_digits: 45/128 (35%) ,Acc_labels: 38/64 (59%)
# Epoch [8/25],Step [16/40],Loss: 2.7814, Acc_digits: 26/80 (32%) ,Acc_labels: 25/40 (62%)
# Time needed to train  0.2493069909978658
#
# Test set: Loss: 2.3192,Acc_digits: 1041/2000 (52%),Acc_labels: 654/1000 65%
# Epoch [9/25],Step [1/64],Loss: 2.5051, Acc_digits: 47/128 (37%) ,Acc_labels: 46/64 (72%)
# Epoch [9/25],Step [2/64],Loss: 2.6086, Acc_digits: 36/128 (28%) ,Acc_labels: 40/64 (62%)
# Epoch [9/25],Step [3/64],Loss: 2.5731, Acc_digits: 39/128 (30%) ,Acc_labels: 35/64 (55%)
# Epoch [9/25],Step [4/64],Loss: 2.5666, Acc_digits: 36/128 (28%) ,Acc_labels: 42/64 (66%)
# Epoch [9/25],Step [5/64],Loss: 2.4575, Acc_digits: 50/128 (39%) ,Acc_labels: 45/64 (70%)
# Epoch [9/25],Step [6/64],Loss: 2.4713, Acc_digits: 44/128 (34%) ,Acc_labels: 34/64 (53%)
# Epoch [9/25],Step [7/64],Loss: 2.4972, Acc_digits: 49/128 (38%) ,Acc_labels: 37/64 (58%)
# Epoch [9/25],Step [8/64],Loss: 2.5835, Acc_digits: 36/128 (28%) ,Acc_labels: 38/64 (59%)
# Epoch [9/25],Step [9/64],Loss: 2.2855, Acc_digits: 53/128 (41%) ,Acc_labels: 42/64 (66%)
# Epoch [9/25],Step [10/64],Loss: 2.5477, Acc_digits: 40/128 (31%) ,Acc_labels: 42/64 (66%)
# Epoch [9/25],Step [11/64],Loss: 2.3857, Acc_digits: 42/128 (33%) ,Acc_labels: 42/64 (66%)
# Epoch [9/25],Step [12/64],Loss: 2.6052, Acc_digits: 42/128 (33%) ,Acc_labels: 45/64 (70%)
# Epoch [9/25],Step [13/64],Loss: 2.3815, Acc_digits: 55/128 (43%) ,Acc_labels: 44/64 (69%)
# Epoch [9/25],Step [14/64],Loss: 2.5767, Acc_digits: 49/128 (38%) ,Acc_labels: 46/64 (72%)
# Epoch [9/25],Step [15/64],Loss: 2.3201, Acc_digits: 51/128 (40%) ,Acc_labels: 46/64 (72%)
# Epoch [9/25],Step [16/40],Loss: 2.5304, Acc_digits: 28/80 (35%) ,Acc_labels: 26/40 (65%)
# Time needed to train  0.25761613599024713
#
# Test set: Loss: 2.1446,Acc_digits: 1154/2000 (58%),Acc_labels: 679/1000 68%
# Epoch [10/25],Step [1/64],Loss: 2.4875, Acc_digits: 46/128 (36%) ,Acc_labels: 35/64 (55%)
# Epoch [10/25],Step [2/64],Loss: 2.5258, Acc_digits: 41/128 (32%) ,Acc_labels: 39/64 (61%)
# Epoch [10/25],Step [3/64],Loss: 2.5942, Acc_digits: 38/128 (30%) ,Acc_labels: 44/64 (69%)
# Epoch [10/25],Step [4/64],Loss: 2.4126, Acc_digits: 46/128 (36%) ,Acc_labels: 38/64 (59%)
# Epoch [10/25],Step [5/64],Loss: 2.5077, Acc_digits: 45/128 (35%) ,Acc_labels: 44/64 (69%)
# Epoch [10/25],Step [6/64],Loss: 2.4893, Acc_digits: 39/128 (30%) ,Acc_labels: 39/64 (61%)
# Epoch [10/25],Step [7/64],Loss: 2.4615, Acc_digits: 51/128 (40%) ,Acc_labels: 40/64 (62%)
# Epoch [10/25],Step [8/64],Loss: 2.3757, Acc_digits: 45/128 (35%) ,Acc_labels: 41/64 (64%)
# Epoch [10/25],Step [9/64],Loss: 2.3960, Acc_digits: 50/128 (39%) ,Acc_labels: 44/64 (69%)
# Epoch [10/25],Step [10/64],Loss: 2.3823, Acc_digits: 42/128 (33%) ,Acc_labels: 43/64 (67%)
# Epoch [10/25],Step [11/64],Loss: 2.2578, Acc_digits: 65/128 (51%) ,Acc_labels: 40/64 (62%)
# Epoch [10/25],Step [12/64],Loss: 2.2197, Acc_digits: 58/128 (45%) ,Acc_labels: 41/64 (64%)
# Epoch [10/25],Step [13/64],Loss: 2.3311, Acc_digits: 53/128 (41%) ,Acc_labels: 48/64 (75%)
# Epoch [10/25],Step [14/64],Loss: 2.4244, Acc_digits: 49/128 (38%) ,Acc_labels: 47/64 (73%)
# Epoch [10/25],Step [15/64],Loss: 2.2332, Acc_digits: 54/128 (42%) ,Acc_labels: 39/64 (61%)
# Epoch [10/25],Step [16/40],Loss: 2.2172, Acc_digits: 38/80 (48%) ,Acc_labels: 32/40 (80%)
# Time needed to train  0.22578862390946597
#
# Test set: Loss: 2.1050,Acc_digits: 1186/2000 (59%),Acc_labels: 693/1000 69%
# Epoch [11/25],Step [1/64],Loss: 2.3769, Acc_digits: 42/128 (33%) ,Acc_labels: 44/64 (69%)
# Epoch [11/25],Step [2/64],Loss: 2.5061, Acc_digits: 49/128 (38%) ,Acc_labels: 37/64 (58%)
# Epoch [11/25],Step [3/64],Loss: 2.2882, Acc_digits: 60/128 (47%) ,Acc_labels: 45/64 (70%)
# Epoch [11/25],Step [4/64],Loss: 2.3869, Acc_digits: 50/128 (39%) ,Acc_labels: 38/64 (59%)
# Epoch [11/25],Step [5/64],Loss: 2.3118, Acc_digits: 52/128 (41%) ,Acc_labels: 44/64 (69%)
# Epoch [11/25],Step [6/64],Loss: 2.3319, Acc_digits: 54/128 (42%) ,Acc_labels: 40/64 (62%)
# Epoch [11/25],Step [7/64],Loss: 2.3813, Acc_digits: 50/128 (39%) ,Acc_labels: 43/64 (67%)
# Epoch [11/25],Step [8/64],Loss: 2.2488, Acc_digits: 57/128 (45%) ,Acc_labels: 40/64 (62%)
# Epoch [11/25],Step [9/64],Loss: 2.3450, Acc_digits: 52/128 (41%) ,Acc_labels: 43/64 (67%)
# Epoch [11/25],Step [10/64],Loss: 2.4337, Acc_digits: 51/128 (40%) ,Acc_labels: 44/64 (69%)
# Epoch [11/25],Step [11/64],Loss: 2.3015, Acc_digits: 55/128 (43%) ,Acc_labels: 41/64 (64%)
# Epoch [11/25],Step [12/64],Loss: 2.2533, Acc_digits: 48/128 (38%) ,Acc_labels: 42/64 (66%)
# Epoch [11/25],Step [13/64],Loss: 2.2709, Acc_digits: 58/128 (45%) ,Acc_labels: 46/64 (72%)
# Epoch [11/25],Step [14/64],Loss: 2.1344, Acc_digits: 61/128 (48%) ,Acc_labels: 49/64 (77%)
# Epoch [11/25],Step [15/64],Loss: 2.3086, Acc_digits: 53/128 (41%) ,Acc_labels: 42/64 (66%)
# Epoch [11/25],Step [16/40],Loss: 2.2771, Acc_digits: 36/80 (45%) ,Acc_labels: 26/40 (65%)
# Time needed to train  0.23253606399521232
#
# Test set: Loss: 1.8870,Acc_digits: 1324/2000 (66%),Acc_labels: 710/1000 71%
# Epoch [12/25],Step [1/64],Loss: 2.2991, Acc_digits: 53/128 (41%) ,Acc_labels: 35/64 (55%)
# Epoch [12/25],Step [2/64],Loss: 2.3078, Acc_digits: 53/128 (41%) ,Acc_labels: 46/64 (72%)
# Epoch [12/25],Step [3/64],Loss: 2.2625, Acc_digits: 52/128 (41%) ,Acc_labels: 38/64 (59%)
# Epoch [12/25],Step [4/64],Loss: 2.3577, Acc_digits: 55/128 (43%) ,Acc_labels: 39/64 (61%)
# Epoch [12/25],Step [5/64],Loss: 2.4718, Acc_digits: 47/128 (37%) ,Acc_labels: 42/64 (66%)
# Epoch [12/25],Step [6/64],Loss: 2.3104, Acc_digits: 58/128 (45%) ,Acc_labels: 42/64 (66%)
# Epoch [12/25],Step [7/64],Loss: 2.1473, Acc_digits: 57/128 (45%) ,Acc_labels: 44/64 (69%)
# Epoch [12/25],Step [8/64],Loss: 2.3242, Acc_digits: 50/128 (39%) ,Acc_labels: 42/64 (66%)
# Epoch [12/25],Step [9/64],Loss: 2.4449, Acc_digits: 53/128 (41%) ,Acc_labels: 38/64 (59%)
# Epoch [12/25],Step [10/64],Loss: 2.1861, Acc_digits: 61/128 (48%) ,Acc_labels: 37/64 (58%)
# Epoch [12/25],Step [11/64],Loss: 2.2421, Acc_digits: 51/128 (40%) ,Acc_labels: 45/64 (70%)
# Epoch [12/25],Step [12/64],Loss: 2.2311, Acc_digits: 59/128 (46%) ,Acc_labels: 39/64 (61%)
# Epoch [12/25],Step [13/64],Loss: 2.1448, Acc_digits: 61/128 (48%) ,Acc_labels: 41/64 (64%)
# Epoch [12/25],Step [14/64],Loss: 2.1945, Acc_digits: 58/128 (45%) ,Acc_labels: 46/64 (72%)
# Epoch [12/25],Step [15/64],Loss: 1.9773, Acc_digits: 67/128 (52%) ,Acc_labels: 49/64 (77%)
# Epoch [12/25],Step [16/40],Loss: 2.3136, Acc_digits: 30/80 (38%) ,Acc_labels: 25/40 (62%)
# Time needed to train  0.23387079301755875
#
# Test set: Loss: 1.8059,Acc_digits: 1384/2000 (69%),Acc_labels: 701/1000 70%
# Epoch [13/25],Step [1/64],Loss: 2.2024, Acc_digits: 55/128 (43%) ,Acc_labels: 42/64 (66%)
# Epoch [13/25],Step [2/64],Loss: 2.2244, Acc_digits: 54/128 (42%) ,Acc_labels: 40/64 (62%)
# Epoch [13/25],Step [3/64],Loss: 2.3586, Acc_digits: 52/128 (41%) ,Acc_labels: 42/64 (66%)
# Epoch [13/25],Step [4/64],Loss: 2.2721, Acc_digits: 56/128 (44%) ,Acc_labels: 39/64 (61%)
# Epoch [13/25],Step [5/64],Loss: 2.1763, Acc_digits: 53/128 (41%) ,Acc_labels: 44/64 (69%)
# Epoch [13/25],Step [6/64],Loss: 2.0870, Acc_digits: 65/128 (51%) ,Acc_labels: 45/64 (70%)
# Epoch [13/25],Step [7/64],Loss: 2.1452, Acc_digits: 66/128 (52%) ,Acc_labels: 45/64 (70%)
# Epoch [13/25],Step [8/64],Loss: 2.2087, Acc_digits: 56/128 (44%) ,Acc_labels: 43/64 (67%)
# Epoch [13/25],Step [9/64],Loss: 2.0366, Acc_digits: 66/128 (52%) ,Acc_labels: 46/64 (72%)
# Epoch [13/25],Step [10/64],Loss: 2.2778, Acc_digits: 56/128 (44%) ,Acc_labels: 44/64 (69%)
# Epoch [13/25],Step [11/64],Loss: 2.1364, Acc_digits: 55/128 (43%) ,Acc_labels: 48/64 (75%)
# Epoch [13/25],Step [12/64],Loss: 2.1988, Acc_digits: 57/128 (45%) ,Acc_labels: 36/64 (56%)
# Epoch [13/25],Step [13/64],Loss: 2.2640, Acc_digits: 59/128 (46%) ,Acc_labels: 39/64 (61%)
# Epoch [13/25],Step [14/64],Loss: 1.9364, Acc_digits: 69/128 (54%) ,Acc_labels: 45/64 (70%)
# Epoch [13/25],Step [15/64],Loss: 2.1251, Acc_digits: 61/128 (48%) ,Acc_labels: 43/64 (67%)
# Epoch [13/25],Step [16/40],Loss: 1.9804, Acc_digits: 39/80 (49%) ,Acc_labels: 29/40 (72%)
# Time needed to train  0.2604986031074077
#
# Test set: Loss: 1.6758,Acc_digits: 1444/2000 (72%),Acc_labels: 702/1000 70%
# Epoch [14/25],Step [1/64],Loss: 1.9286, Acc_digits: 71/128 (55%) ,Acc_labels: 46/64 (72%)
# Epoch [14/25],Step [2/64],Loss: 2.3450, Acc_digits: 54/128 (42%) ,Acc_labels: 41/64 (64%)
# Epoch [14/25],Step [3/64],Loss: 1.9431, Acc_digits: 64/128 (50%) ,Acc_labels: 52/64 (81%)
# Epoch [14/25],Step [4/64],Loss: 1.9690, Acc_digits: 66/128 (52%) ,Acc_labels: 45/64 (70%)
# Epoch [14/25],Step [5/64],Loss: 2.1792, Acc_digits: 59/128 (46%) ,Acc_labels: 39/64 (61%)
# Epoch [14/25],Step [6/64],Loss: 1.9931, Acc_digits: 58/128 (45%) ,Acc_labels: 50/64 (78%)
# Epoch [14/25],Step [7/64],Loss: 2.0647, Acc_digits: 71/128 (55%) ,Acc_labels: 38/64 (59%)
# Epoch [14/25],Step [8/64],Loss: 2.0946, Acc_digits: 55/128 (43%) ,Acc_labels: 41/64 (64%)
# Epoch [14/25],Step [9/64],Loss: 2.1923, Acc_digits: 58/128 (45%) ,Acc_labels: 46/64 (72%)
# Epoch [14/25],Step [10/64],Loss: 2.2889, Acc_digits: 55/128 (43%) ,Acc_labels: 41/64 (64%)
# Epoch [14/25],Step [11/64],Loss: 2.0927, Acc_digits: 64/128 (50%) ,Acc_labels: 46/64 (72%)
# Epoch [14/25],Step [12/64],Loss: 2.2293, Acc_digits: 55/128 (43%) ,Acc_labels: 43/64 (67%)
# Epoch [14/25],Step [13/64],Loss: 1.8809, Acc_digits: 69/128 (54%) ,Acc_labels: 38/64 (59%)
# Epoch [14/25],Step [14/64],Loss: 2.0810, Acc_digits: 59/128 (46%) ,Acc_labels: 46/64 (72%)
# Epoch [14/25],Step [15/64],Loss: 1.9889, Acc_digits: 60/128 (47%) ,Acc_labels: 47/64 (73%)
# Epoch [14/25],Step [16/40],Loss: 1.9533, Acc_digits: 45/80 (56%) ,Acc_labels: 28/40 (70%)
# Time needed to train  0.26177050406113267
#
# Test set: Loss: 1.6609,Acc_digits: 1506/2000 (75%),Acc_labels: 690/1000 69%
# Epoch [15/25],Step [1/64],Loss: 1.9757, Acc_digits: 61/128 (48%) ,Acc_labels: 46/64 (72%)
# Epoch [15/25],Step [2/64],Loss: 2.0422, Acc_digits: 64/128 (50%) ,Acc_labels: 42/64 (66%)
# Epoch [15/25],Step [3/64],Loss: 2.1265, Acc_digits: 56/128 (44%) ,Acc_labels: 44/64 (69%)
# Epoch [15/25],Step [4/64],Loss: 1.9573, Acc_digits: 71/128 (55%) ,Acc_labels: 40/64 (62%)
# Epoch [15/25],Step [5/64],Loss: 2.0112, Acc_digits: 67/128 (52%) ,Acc_labels: 48/64 (75%)
# Epoch [15/25],Step [6/64],Loss: 2.1645, Acc_digits: 61/128 (48%) ,Acc_labels: 37/64 (58%)
# Epoch [15/25],Step [7/64],Loss: 2.0884, Acc_digits: 65/128 (51%) ,Acc_labels: 37/64 (58%)
# Epoch [15/25],Step [8/64],Loss: 2.1585, Acc_digits: 61/128 (48%) ,Acc_labels: 41/64 (64%)
# Epoch [15/25],Step [9/64],Loss: 1.9376, Acc_digits: 65/128 (51%) ,Acc_labels: 43/64 (67%)
# Epoch [15/25],Step [10/64],Loss: 2.0000, Acc_digits: 65/128 (51%) ,Acc_labels: 40/64 (62%)
# Epoch [15/25],Step [11/64],Loss: 1.9525, Acc_digits: 65/128 (51%) ,Acc_labels: 44/64 (69%)
# Epoch [15/25],Step [12/64],Loss: 2.0899, Acc_digits: 54/128 (42%) ,Acc_labels: 45/64 (70%)
# Epoch [15/25],Step [13/64],Loss: 2.0308, Acc_digits: 60/128 (47%) ,Acc_labels: 47/64 (73%)
# Epoch [15/25],Step [14/64],Loss: 2.1609, Acc_digits: 61/128 (48%) ,Acc_labels: 36/64 (56%)
# Epoch [15/25],Step [15/64],Loss: 2.1928, Acc_digits: 58/128 (45%) ,Acc_labels: 44/64 (69%)
# Epoch [15/25],Step [16/40],Loss: 1.9108, Acc_digits: 44/80 (55%) ,Acc_labels: 32/40 (80%)
# Time needed to train  0.22380354697816074
#
# Test set: Loss: 1.5597,Acc_digits: 1569/2000 (78%),Acc_labels: 707/1000 71%
# Epoch [16/25],Step [1/64],Loss: 1.9080, Acc_digits: 70/128 (55%) ,Acc_labels: 44/64 (69%)
# Epoch [16/25],Step [2/64],Loss: 1.9902, Acc_digits: 68/128 (53%) ,Acc_labels: 41/64 (64%)
# Epoch [16/25],Step [3/64],Loss: 2.0819, Acc_digits: 59/128 (46%) ,Acc_labels: 43/64 (67%)
# Epoch [16/25],Step [4/64],Loss: 1.8163, Acc_digits: 69/128 (54%) ,Acc_labels: 42/64 (66%)
# Epoch [16/25],Step [5/64],Loss: 2.0812, Acc_digits: 60/128 (47%) ,Acc_labels: 43/64 (67%)
# Epoch [16/25],Step [6/64],Loss: 1.8027, Acc_digits: 78/128 (61%) ,Acc_labels: 46/64 (72%)
# Epoch [16/25],Step [7/64],Loss: 1.9530, Acc_digits: 66/128 (52%) ,Acc_labels: 43/64 (67%)
# Epoch [16/25],Step [8/64],Loss: 1.9197, Acc_digits: 67/128 (52%) ,Acc_labels: 43/64 (67%)
# Epoch [16/25],Step [9/64],Loss: 1.9813, Acc_digits: 63/128 (49%) ,Acc_labels: 44/64 (69%)
# Epoch [16/25],Step [10/64],Loss: 1.9043, Acc_digits: 68/128 (53%) ,Acc_labels: 47/64 (73%)
# Epoch [16/25],Step [11/64],Loss: 1.9302, Acc_digits: 63/128 (49%) ,Acc_labels: 44/64 (69%)
# Epoch [16/25],Step [12/64],Loss: 2.0922, Acc_digits: 67/128 (52%) ,Acc_labels: 38/64 (59%)
# Epoch [16/25],Step [13/64],Loss: 1.7814, Acc_digits: 73/128 (57%) ,Acc_labels: 45/64 (70%)
# Epoch [16/25],Step [14/64],Loss: 2.0784, Acc_digits: 64/128 (50%) ,Acc_labels: 44/64 (69%)
# Epoch [16/25],Step [15/64],Loss: 2.0518, Acc_digits: 64/128 (50%) ,Acc_labels: 42/64 (66%)
# Epoch [16/25],Step [16/40],Loss: 2.2882, Acc_digits: 37/80 (46%) ,Acc_labels: 27/40 (68%)
# Time needed to train  0.22133442596532404
#
# Test set: Loss: 1.5148,Acc_digits: 1589/2000 (79%),Acc_labels: 724/1000 72%
# Epoch [17/25],Step [1/64],Loss: 1.7118, Acc_digits: 76/128 (59%) ,Acc_labels: 42/64 (66%)
# Epoch [17/25],Step [2/64],Loss: 2.0752, Acc_digits: 62/128 (48%) ,Acc_labels: 48/64 (75%)
# Epoch [17/25],Step [3/64],Loss: 2.0008, Acc_digits: 58/128 (45%) ,Acc_labels: 52/64 (81%)
# Epoch [17/25],Step [4/64],Loss: 1.8884, Acc_digits: 67/128 (52%) ,Acc_labels: 42/64 (66%)
# Epoch [17/25],Step [5/64],Loss: 1.9400, Acc_digits: 65/128 (51%) ,Acc_labels: 42/64 (66%)
# Epoch [17/25],Step [6/64],Loss: 1.6882, Acc_digits: 77/128 (60%) ,Acc_labels: 46/64 (72%)
# Epoch [17/25],Step [7/64],Loss: 1.9528, Acc_digits: 70/128 (55%) ,Acc_labels: 41/64 (64%)
# Epoch [17/25],Step [8/64],Loss: 1.8907, Acc_digits: 72/128 (56%) ,Acc_labels: 46/64 (72%)
# Epoch [17/25],Step [9/64],Loss: 2.0005, Acc_digits: 68/128 (53%) ,Acc_labels: 49/64 (77%)
# Epoch [17/25],Step [10/64],Loss: 1.9981, Acc_digits: 65/128 (51%) ,Acc_labels: 47/64 (73%)
# Epoch [17/25],Step [11/64],Loss: 1.8879, Acc_digits: 71/128 (55%) ,Acc_labels: 46/64 (72%)
# Epoch [17/25],Step [12/64],Loss: 1.9303, Acc_digits: 62/128 (48%) ,Acc_labels: 46/64 (72%)
# Epoch [17/25],Step [13/64],Loss: 1.7272, Acc_digits: 75/128 (59%) ,Acc_labels: 46/64 (72%)
# Epoch [17/25],Step [14/64],Loss: 1.9922, Acc_digits: 68/128 (53%) ,Acc_labels: 45/64 (70%)
# Epoch [17/25],Step [15/64],Loss: 1.9202, Acc_digits: 66/128 (52%) ,Acc_labels: 48/64 (75%)
# Epoch [17/25],Step [16/40],Loss: 2.1168, Acc_digits: 35/80 (44%) ,Acc_labels: 26/40 (65%)
# Time needed to train  0.2636948359431699
#
# Test set: Loss: 1.4218,Acc_digits: 1611/2000 (81%),Acc_labels: 725/1000 72%
# Epoch [18/25],Step [1/64],Loss: 1.9105, Acc_digits: 71/128 (55%) ,Acc_labels: 39/64 (61%)
# Epoch [18/25],Step [2/64],Loss: 1.9762, Acc_digits: 66/128 (52%) ,Acc_labels: 44/64 (69%)
# Epoch [18/25],Step [3/64],Loss: 1.9102, Acc_digits: 69/128 (54%) ,Acc_labels: 40/64 (62%)
# Epoch [18/25],Step [4/64],Loss: 1.7721, Acc_digits: 73/128 (57%) ,Acc_labels: 49/64 (77%)
# Epoch [18/25],Step [5/64],Loss: 1.6909, Acc_digits: 76/128 (59%) ,Acc_labels: 46/64 (72%)
# Epoch [18/25],Step [6/64],Loss: 1.6156, Acc_digits: 78/128 (61%) ,Acc_labels: 48/64 (75%)
# Epoch [18/25],Step [7/64],Loss: 1.9410, Acc_digits: 72/128 (56%) ,Acc_labels: 46/64 (72%)
# Epoch [18/25],Step [8/64],Loss: 2.0089, Acc_digits: 64/128 (50%) ,Acc_labels: 44/64 (69%)
# Epoch [18/25],Step [9/64],Loss: 1.6912, Acc_digits: 81/128 (63%) ,Acc_labels: 47/64 (73%)
# Epoch [18/25],Step [10/64],Loss: 1.8730, Acc_digits: 65/128 (51%) ,Acc_labels: 42/64 (66%)
# Epoch [18/25],Step [11/64],Loss: 1.7837, Acc_digits: 77/128 (60%) ,Acc_labels: 46/64 (72%)
# Epoch [18/25],Step [12/64],Loss: 1.9230, Acc_digits: 71/128 (55%) ,Acc_labels: 39/64 (61%)
# Epoch [18/25],Step [13/64],Loss: 1.7998, Acc_digits: 68/128 (53%) ,Acc_labels: 41/64 (64%)
# Epoch [18/25],Step [14/64],Loss: 1.9093, Acc_digits: 62/128 (48%) ,Acc_labels: 45/64 (70%)
# Epoch [18/25],Step [15/64],Loss: 1.7698, Acc_digits: 72/128 (56%) ,Acc_labels: 44/64 (69%)
# Epoch [18/25],Step [16/40],Loss: 1.7136, Acc_digits: 54/80 (68%) ,Acc_labels: 29/40 (72%)
# Time needed to train  0.23289154202211648
#
# Test set: Loss: 1.3391,Acc_digits: 1623/2000 (81%),Acc_labels: 739/1000 74%
# Epoch [19/25],Step [1/64],Loss: 1.8188, Acc_digits: 72/128 (56%) ,Acc_labels: 48/64 (75%)
# Epoch [19/25],Step [2/64],Loss: 1.9320, Acc_digits: 75/128 (59%) ,Acc_labels: 36/64 (56%)
# Epoch [19/25],Step [3/64],Loss: 1.7283, Acc_digits: 75/128 (59%) ,Acc_labels: 46/64 (72%)
# Epoch [19/25],Step [4/64],Loss: 1.9557, Acc_digits: 67/128 (52%) ,Acc_labels: 44/64 (69%)
# Epoch [19/25],Step [5/64],Loss: 2.0067, Acc_digits: 67/128 (52%) ,Acc_labels: 40/64 (62%)
# Epoch [19/25],Step [6/64],Loss: 1.7497, Acc_digits: 69/128 (54%) ,Acc_labels: 46/64 (72%)
# Epoch [19/25],Step [7/64],Loss: 1.5532, Acc_digits: 84/128 (66%) ,Acc_labels: 45/64 (70%)
# Epoch [19/25],Step [8/64],Loss: 1.8037, Acc_digits: 77/128 (60%) ,Acc_labels: 41/64 (64%)
# Epoch [19/25],Step [9/64],Loss: 1.7743, Acc_digits: 78/128 (61%) ,Acc_labels: 47/64 (73%)
# Epoch [19/25],Step [10/64],Loss: 1.8054, Acc_digits: 78/128 (61%) ,Acc_labels: 48/64 (75%)
# Epoch [19/25],Step [11/64],Loss: 1.9519, Acc_digits: 69/128 (54%) ,Acc_labels: 43/64 (67%)
# Epoch [19/25],Step [12/64],Loss: 1.8576, Acc_digits: 71/128 (55%) ,Acc_labels: 41/64 (64%)
# Epoch [19/25],Step [13/64],Loss: 1.7776, Acc_digits: 67/128 (52%) ,Acc_labels: 52/64 (81%)
# Epoch [19/25],Step [14/64],Loss: 1.5679, Acc_digits: 79/128 (62%) ,Acc_labels: 45/64 (70%)
# Epoch [19/25],Step [15/64],Loss: 1.7563, Acc_digits: 74/128 (58%) ,Acc_labels: 46/64 (72%)
# Epoch [19/25],Step [16/40],Loss: 2.0549, Acc_digits: 43/80 (54%) ,Acc_labels: 27/40 (68%)
# Time needed to train  0.25082499196287245
#
# Test set: Loss: 1.2956,Acc_digits: 1660/2000 (83%),Acc_labels: 740/1000 74%
# Epoch [20/25],Step [1/64],Loss: 1.6937, Acc_digits: 69/128 (54%) ,Acc_labels: 50/64 (78%)
# Epoch [20/25],Step [2/64],Loss: 1.8657, Acc_digits: 73/128 (57%) ,Acc_labels: 46/64 (72%)
# Epoch [20/25],Step [3/64],Loss: 1.6515, Acc_digits: 75/128 (59%) ,Acc_labels: 43/64 (67%)
# Epoch [20/25],Step [4/64],Loss: 2.0461, Acc_digits: 63/128 (49%) ,Acc_labels: 45/64 (70%)
# Epoch [20/25],Step [5/64],Loss: 1.6857, Acc_digits: 78/128 (61%) ,Acc_labels: 48/64 (75%)
# Epoch [20/25],Step [6/64],Loss: 1.9213, Acc_digits: 65/128 (51%) ,Acc_labels: 44/64 (69%)
# Epoch [20/25],Step [7/64],Loss: 1.9858, Acc_digits: 67/128 (52%) ,Acc_labels: 40/64 (62%)
# Epoch [20/25],Step [8/64],Loss: 1.7720, Acc_digits: 81/128 (63%) ,Acc_labels: 41/64 (64%)
# Epoch [20/25],Step [9/64],Loss: 1.7900, Acc_digits: 72/128 (56%) ,Acc_labels: 48/64 (75%)
# Epoch [20/25],Step [10/64],Loss: 1.8520, Acc_digits: 70/128 (55%) ,Acc_labels: 51/64 (80%)
# Epoch [20/25],Step [11/64],Loss: 1.9763, Acc_digits: 66/128 (52%) ,Acc_labels: 38/64 (59%)
# Epoch [20/25],Step [12/64],Loss: 1.6650, Acc_digits: 83/128 (65%) ,Acc_labels: 41/64 (64%)
# Epoch [20/25],Step [13/64],Loss: 1.7928, Acc_digits: 76/128 (59%) ,Acc_labels: 45/64 (70%)
# Epoch [20/25],Step [14/64],Loss: 1.6680, Acc_digits: 84/128 (66%) ,Acc_labels: 41/64 (64%)
# Epoch [20/25],Step [15/64],Loss: 1.6958, Acc_digits: 77/128 (60%) ,Acc_labels: 48/64 (75%)
# Epoch [20/25],Step [16/40],Loss: 1.7367, Acc_digits: 45/80 (56%) ,Acc_labels: 27/40 (68%)
# Time needed to train  0.2601773419883102
#
# Test set: Loss: 1.2077,Acc_digits: 1664/2000 (83%),Acc_labels: 756/1000 76%
# Epoch [21/25],Step [1/64],Loss: 1.7726, Acc_digits: 71/128 (55%) ,Acc_labels: 45/64 (70%)
# Epoch [21/25],Step [2/64],Loss: 2.0766, Acc_digits: 65/128 (51%) ,Acc_labels: 43/64 (67%)
# Epoch [21/25],Step [3/64],Loss: 1.8995, Acc_digits: 73/128 (57%) ,Acc_labels: 44/64 (69%)
# Epoch [21/25],Step [4/64],Loss: 1.5885, Acc_digits: 77/128 (60%) ,Acc_labels: 47/64 (73%)
# Epoch [21/25],Step [5/64],Loss: 1.7221, Acc_digits: 85/128 (66%) ,Acc_labels: 51/64 (80%)
# Epoch [21/25],Step [6/64],Loss: 1.8364, Acc_digits: 75/128 (59%) ,Acc_labels: 36/64 (56%)
# Epoch [21/25],Step [7/64],Loss: 1.7877, Acc_digits: 71/128 (55%) ,Acc_labels: 46/64 (72%)
# Epoch [21/25],Step [8/64],Loss: 1.9035, Acc_digits: 68/128 (53%) ,Acc_labels: 45/64 (70%)
# Epoch [21/25],Step [9/64],Loss: 1.7821, Acc_digits: 73/128 (57%) ,Acc_labels: 45/64 (70%)
# Epoch [21/25],Step [10/64],Loss: 1.7379, Acc_digits: 74/128 (58%) ,Acc_labels: 47/64 (73%)
# Epoch [21/25],Step [11/64],Loss: 1.9624, Acc_digits: 68/128 (53%) ,Acc_labels: 38/64 (59%)
# Epoch [21/25],Step [12/64],Loss: 1.7664, Acc_digits: 72/128 (56%) ,Acc_labels: 45/64 (70%)
# Epoch [21/25],Step [13/64],Loss: 1.8891, Acc_digits: 66/128 (52%) ,Acc_labels: 41/64 (64%)
# Epoch [21/25],Step [14/64],Loss: 1.8213, Acc_digits: 70/128 (55%) ,Acc_labels: 46/64 (72%)
# Epoch [21/25],Step [15/64],Loss: 1.9316, Acc_digits: 77/128 (60%) ,Acc_labels: 37/64 (58%)
# Epoch [21/25],Step [16/40],Loss: 1.8429, Acc_digits: 43/80 (54%) ,Acc_labels: 28/40 (70%)
# Time needed to train  0.23328422103077173
#
# Test set: Loss: 1.2695,Acc_digits: 1677/2000 (84%),Acc_labels: 735/1000 74%
# Epoch [22/25],Step [1/64],Loss: 1.8118, Acc_digits: 75/128 (59%) ,Acc_labels: 37/64 (58%)
# Epoch [22/25],Step [2/64],Loss: 1.7894, Acc_digits: 62/128 (48%) ,Acc_labels: 54/64 (84%)
# Epoch [22/25],Step [3/64],Loss: 1.8179, Acc_digits: 79/128 (62%) ,Acc_labels: 47/64 (73%)
# Epoch [22/25],Step [4/64],Loss: 1.8474, Acc_digits: 70/128 (55%) ,Acc_labels: 42/64 (66%)
# Epoch [22/25],Step [5/64],Loss: 1.8231, Acc_digits: 82/128 (64%) ,Acc_labels: 45/64 (70%)
# Epoch [22/25],Step [6/64],Loss: 2.1768, Acc_digits: 66/128 (52%) ,Acc_labels: 47/64 (73%)
# Epoch [22/25],Step [7/64],Loss: 1.5052, Acc_digits: 92/128 (72%) ,Acc_labels: 45/64 (70%)
# Epoch [22/25],Step [8/64],Loss: 1.5199, Acc_digits: 88/128 (69%) ,Acc_labels: 49/64 (77%)
# Epoch [22/25],Step [9/64],Loss: 1.9694, Acc_digits: 69/128 (54%) ,Acc_labels: 40/64 (62%)
# Epoch [22/25],Step [10/64],Loss: 1.9990, Acc_digits: 64/128 (50%) ,Acc_labels: 43/64 (67%)
# Epoch [22/25],Step [11/64],Loss: 2.0866, Acc_digits: 67/128 (52%) ,Acc_labels: 44/64 (69%)
# Epoch [22/25],Step [12/64],Loss: 1.9393, Acc_digits: 70/128 (55%) ,Acc_labels: 42/64 (66%)
# Epoch [22/25],Step [13/64],Loss: 1.8125, Acc_digits: 74/128 (58%) ,Acc_labels: 44/64 (69%)
# Epoch [22/25],Step [14/64],Loss: 1.4837, Acc_digits: 79/128 (62%) ,Acc_labels: 53/64 (83%)
# Epoch [22/25],Step [15/64],Loss: 1.8353, Acc_digits: 70/128 (55%) ,Acc_labels: 44/64 (69%)
# Epoch [22/25],Step [16/40],Loss: 2.0914, Acc_digits: 38/80 (48%) ,Acc_labels: 24/40 (60%)
# Time needed to train  0.2327529959147796
#
# Test set: Loss: 1.2106,Acc_digits: 1709/2000 (85%),Acc_labels: 744/1000 74%
# Epoch [23/25],Step [1/64],Loss: 1.8306, Acc_digits: 77/128 (60%) ,Acc_labels: 43/64 (67%)
# Epoch [23/25],Step [2/64],Loss: 1.8668, Acc_digits: 72/128 (56%) ,Acc_labels: 48/64 (75%)
# Epoch [23/25],Step [3/64],Loss: 1.8043, Acc_digits: 73/128 (57%) ,Acc_labels: 42/64 (66%)
# Epoch [23/25],Step [4/64],Loss: 1.5886, Acc_digits: 73/128 (57%) ,Acc_labels: 46/64 (72%)
# Epoch [23/25],Step [5/64],Loss: 1.8740, Acc_digits: 76/128 (59%) ,Acc_labels: 42/64 (66%)
# Epoch [23/25],Step [6/64],Loss: 1.9399, Acc_digits: 71/128 (55%) ,Acc_labels: 40/64 (62%)
# Epoch [23/25],Step [7/64],Loss: 1.7984, Acc_digits: 65/128 (51%) ,Acc_labels: 50/64 (78%)
# Epoch [23/25],Step [8/64],Loss: 1.8493, Acc_digits: 70/128 (55%) ,Acc_labels: 47/64 (73%)
# Epoch [23/25],Step [9/64],Loss: 1.6413, Acc_digits: 78/128 (61%) ,Acc_labels: 47/64 (73%)
# Epoch [23/25],Step [10/64],Loss: 1.8078, Acc_digits: 68/128 (53%) ,Acc_labels: 47/64 (73%)
# Epoch [23/25],Step [11/64],Loss: 1.6291, Acc_digits: 81/128 (63%) ,Acc_labels: 43/64 (67%)
# Epoch [23/25],Step [12/64],Loss: 1.6774, Acc_digits: 85/128 (66%) ,Acc_labels: 44/64 (69%)
# Epoch [23/25],Step [13/64],Loss: 1.7653, Acc_digits: 70/128 (55%) ,Acc_labels: 44/64 (69%)
# Epoch [23/25],Step [14/64],Loss: 1.5735, Acc_digits: 83/128 (65%) ,Acc_labels: 46/64 (72%)
# Epoch [23/25],Step [15/64],Loss: 1.5248, Acc_digits: 76/128 (59%) ,Acc_labels: 49/64 (77%)
# Epoch [23/25],Step [16/40],Loss: 1.7290, Acc_digits: 44/80 (55%) ,Acc_labels: 27/40 (68%)
# Time needed to train  0.2947799119865522
#
# Test set: Loss: 1.1496,Acc_digits: 1698/2000 (85%),Acc_labels: 744/1000 74%
# Epoch [24/25],Step [1/64],Loss: 1.7168, Acc_digits: 73/128 (57%) ,Acc_labels: 51/64 (80%)
# Epoch [24/25],Step [2/64],Loss: 1.6303, Acc_digits: 86/128 (67%) ,Acc_labels: 46/64 (72%)
# Epoch [24/25],Step [3/64],Loss: 1.6241, Acc_digits: 72/128 (56%) ,Acc_labels: 48/64 (75%)
# Epoch [24/25],Step [4/64],Loss: 1.4923, Acc_digits: 81/128 (63%) ,Acc_labels: 53/64 (83%)
# Epoch [24/25],Step [5/64],Loss: 1.6660, Acc_digits: 79/128 (62%) ,Acc_labels: 45/64 (70%)
# Epoch [24/25],Step [6/64],Loss: 1.7538, Acc_digits: 82/128 (64%) ,Acc_labels: 45/64 (70%)
# Epoch [24/25],Step [7/64],Loss: 1.6572, Acc_digits: 76/128 (59%) ,Acc_labels: 49/64 (77%)
# Epoch [24/25],Step [8/64],Loss: 1.8674, Acc_digits: 71/128 (55%) ,Acc_labels: 46/64 (72%)
# Epoch [24/25],Step [9/64],Loss: 1.7404, Acc_digits: 79/128 (62%) ,Acc_labels: 45/64 (70%)
# Epoch [24/25],Step [10/64],Loss: 1.5889, Acc_digits: 80/128 (62%) ,Acc_labels: 47/64 (73%)
# Epoch [24/25],Step [11/64],Loss: 1.5567, Acc_digits: 82/128 (64%) ,Acc_labels: 47/64 (73%)
# Epoch [24/25],Step [12/64],Loss: 1.7488, Acc_digits: 74/128 (58%) ,Acc_labels: 42/64 (66%)
# Epoch [24/25],Step [13/64],Loss: 1.7626, Acc_digits: 74/128 (58%) ,Acc_labels: 46/64 (72%)
# Epoch [24/25],Step [14/64],Loss: 1.7691, Acc_digits: 69/128 (54%) ,Acc_labels: 44/64 (69%)
# Epoch [24/25],Step [15/64],Loss: 1.6174, Acc_digits: 78/128 (61%) ,Acc_labels: 50/64 (78%)
# Epoch [24/25],Step [16/40],Loss: 2.1277, Acc_digits: 40/80 (50%) ,Acc_labels: 24/40 (60%)
# Time needed to train  0.2525310469791293
# Test set: Loss: 1.1417,Acc_digits: 1706/2000 (85%),Acc_labels: 761/1000 76%
# Epoch [25/25],Step [1/64],Loss: 1.7866, Acc_digits: 77/128 (60%) ,Acc_labels: 40/64 (62%)
# Epoch [25/25],Step [2/64],Loss: 1.7608, Acc_digits: 76/128 (59%) ,Acc_labels: 48/64 (75%)
# Epoch [25/25],Step [3/64],Loss: 1.8331, Acc_digits: 70/128 (55%) ,Acc_labels: 44/64 (69%)
# Epoch [25/25],Step [4/64],Loss: 1.6570, Acc_digits: 79/128 (62%) ,Acc_labels: 51/64 (80%)
# Epoch [25/25],Step [5/64],Loss: 1.9482, Acc_digits: 64/128 (50%) ,Acc_labels: 45/64 (70%)
# Epoch [25/25],Step [6/64],Loss: 1.7536, Acc_digits: 76/128 (59%) ,Acc_labels: 47/64 (73%)
# Epoch [25/25],Step [7/64],Loss: 1.7529, Acc_digits: 76/128 (59%) ,Acc_labels: 49/64 (77%)
# Epoch [25/25],Step [8/64],Loss: 1.6429, Acc_digits: 87/128 (68%) ,Acc_labels: 43/64 (67%)
# Epoch [25/25],Step [9/64],Loss: 1.7062, Acc_digits: 78/128 (61%) ,Acc_labels: 43/64 (67%)
# Epoch [25/25],Step [10/64],Loss: 1.4696, Acc_digits: 79/128 (62%) ,Acc_labels: 53/64 (83%)
# Epoch [25/25],Step [11/64],Loss: 1.7066, Acc_digits: 79/128 (62%) ,Acc_labels: 42/64 (66%)
# Epoch [25/25],Step [12/64],Loss: 1.5068, Acc_digits: 76/128 (59%) ,Acc_labels: 49/64 (77%)
# Epoch [25/25],Step [13/64],Loss: 1.4471, Acc_digits: 86/128 (67%) ,Acc_labels: 55/64 (86%)
# Epoch [25/25],Step [14/64],Loss: 1.6071, Acc_digits: 78/128 (61%) ,Acc_labels: 44/64 (69%)
# Epoch [25/25],Step [15/64],Loss: 1.8932, Acc_digits: 73/128 (57%) ,Acc_labels: 49/64 (77%)
# Epoch [25/25],Step [16/40],Loss: 1.6800, Acc_digits: 55/80 (69%) ,Acc_labels: 28/40 (70%)
# Time needed to train  0.2656065699411556
#
# Test set: Loss: 1.1320,Acc_digits: 1704/2000 (85%),Acc_labels: 755/1000 76%
# Epoch [26/25],Step [1/64],Loss: 1.5843, Acc_digits: 82/128 (64%) ,Acc_labels: 46/64 (72%)
# Epoch [26/25],Step [2/64],Loss: 1.6310, Acc_digits: 86/128 (67%) ,Acc_labels: 46/64 (72%)
# Epoch [26/25],Step [3/64],Loss: 1.8728, Acc_digits: 79/128 (62%) ,Acc_labels: 49/64 (77%)
# Epoch [26/25],Step [4/64],Loss: 1.8106, Acc_digits: 69/128 (54%) ,Acc_labels: 45/64 (70%)
# Epoch [26/25],Step [5/64],Loss: 1.4766, Acc_digits: 92/128 (72%) ,Acc_labels: 54/64 (84%)
# Epoch [26/25],Step [6/64],Loss: 1.6796, Acc_digits: 78/128 (61%) ,Acc_labels: 46/64 (72%)
# Epoch [26/25],Step [7/64],Loss: 1.8618, Acc_digits: 70/128 (55%) ,Acc_labels: 43/64 (67%)
# Epoch [26/25],Step [8/64],Loss: 1.5344, Acc_digits: 79/128 (62%) ,Acc_labels: 46/64 (72%)
# Epoch [26/25],Step [9/64],Loss: 1.7903, Acc_digits: 73/128 (57%) ,Acc_labels: 40/64 (62%)
# Epoch [26/25],Step [10/64],Loss: 1.6401, Acc_digits: 77/128 (60%) ,Acc_labels: 47/64 (73%)
# Epoch [26/25],Step [11/64],Loss: 1.7381, Acc_digits: 76/128 (59%) ,Acc_labels: 49/64 (77%)
# Epoch [26/25],Step [12/64],Loss: 1.5021, Acc_digits: 84/128 (66%) ,Acc_labels: 51/64 (80%)
# Epoch [26/25],Step [13/64],Loss: 1.6695, Acc_digits: 86/128 (67%) ,Acc_labels: 44/64 (69%)
# Epoch [26/25],Step [14/64],Loss: 1.7231, Acc_digits: 76/128 (59%) ,Acc_labels: 50/64 (78%)
# Epoch [26/25],Step [15/64],Loss: 1.6170, Acc_digits: 72/128 (56%) ,Acc_labels: 49/64 (77%)
# Epoch [26/25],Step [16/40],Loss: 1.2305, Acc_digits: 61/80 (76%) ,Acc_labels: 31/40 (78%)
# Time needed to train  0.2543478150619194
#
# Test set: Loss: 1.0523,Acc_digits: 1750/2000 (88%),Acc_labels: 768/1000 77%
# *************************** Start of the Network 1 ***************************
#
#  The number of parameters of the network is
#   69928
# Epoch [2/25],Step [1/64],Loss: 3.7176 ,Acc_labels: 31/64 (48%)
# Epoch [2/25],Step [2/64],Loss: 86.2874 ,Acc_labels: 28/64 (44%)
# Epoch [2/25],Step [3/64],Loss: 0.9009 ,Acc_labels: 37/64 (58%)
# Epoch [2/25],Step [4/64],Loss: 0.6838 ,Acc_labels: 37/64 (58%)
# Epoch [2/25],Step [5/64],Loss: 0.6983 ,Acc_labels: 35/64 (55%)
# Epoch [2/25],Step [6/64],Loss: 0.7115 ,Acc_labels: 32/64 (50%)
# Epoch [2/25],Step [7/64],Loss: 0.7114 ,Acc_labels: 32/64 (50%)
# Epoch [2/25],Step [8/64],Loss: 0.6895 ,Acc_labels: 33/64 (52%)
# Epoch [2/25],Step [9/64],Loss: 0.6881 ,Acc_labels: 33/64 (52%)
# Epoch [2/25],Step [10/64],Loss: 0.6878 ,Acc_labels: 32/64 (50%)
# Epoch [2/25],Step [11/64],Loss: 0.6588 ,Acc_labels: 43/64 (67%)
# Epoch [2/25],Step [12/64],Loss: 0.6961 ,Acc_labels: 36/64 (56%)
# Epoch [2/25],Step [13/64],Loss: 0.7054 ,Acc_labels: 34/64 (53%)
# Epoch [2/25],Step [14/64],Loss: 0.7024 ,Acc_labels: 31/64 (48%)
# Epoch [2/25],Step [15/64],Loss: 0.6585 ,Acc_labels: 40/64 (62%)
# Epoch [2/25],Step [16/40],Loss: 0.6384 ,Acc_labels: 25/40 (62%)
#
#  Time needed to train  0.42782201105728745
#
# Test set: Loss: 0.6786,Acc_labels: 560/1000 56%
# Epoch [3/25],Step [1/64],Loss: 0.7462 ,Acc_labels: 26/64 (41%)
# Epoch [3/25],Step [2/64],Loss: 0.6791 ,Acc_labels: 33/64 (52%)
# Epoch [3/25],Step [3/64],Loss: 0.6898 ,Acc_labels: 33/64 (52%)
# Epoch [3/25],Step [4/64],Loss: 0.6690 ,Acc_labels: 38/64 (59%)
# Epoch [3/25],Step [5/64],Loss: 0.6314 ,Acc_labels: 44/64 (69%)
# Epoch [3/25],Step [6/64],Loss: 0.6462 ,Acc_labels: 43/64 (67%)
# Epoch [3/25],Step [7/64],Loss: 0.6816 ,Acc_labels: 36/64 (56%)
# Epoch [3/25],Step [8/64],Loss: 0.6567 ,Acc_labels: 36/64 (56%)
# Epoch [3/25],Step [9/64],Loss: 0.7516 ,Acc_labels: 35/64 (55%)
# Epoch [3/25],Step [10/64],Loss: 0.6371 ,Acc_labels: 41/64 (64%)
# Epoch [3/25],Step [11/64],Loss: 0.6441 ,Acc_labels: 41/64 (64%)
# Epoch [3/25],Step [12/64],Loss: 0.6148 ,Acc_labels: 46/64 (72%)
# Epoch [3/25],Step [13/64],Loss: 0.6253 ,Acc_labels: 43/64 (67%)
# Epoch [3/25],Step [14/64],Loss: 0.5442 ,Acc_labels: 46/64 (72%)
# Epoch [3/25],Step [15/64],Loss: 0.5480 ,Acc_labels: 41/64 (64%)
# Epoch [3/25],Step [16/40],Loss: 0.7151 ,Acc_labels: 23/40 (57%)
#
#  Time needed to train  0.38808678404893726
#
# Test set: Loss: 0.6183,Acc_labels: 691/1000 69%
# Epoch [4/25],Step [1/64],Loss: 0.6398 ,Acc_labels: 47/64 (73%)
# Epoch [4/25],Step [2/64],Loss: 0.6219 ,Acc_labels: 44/64 (69%)
# Epoch [4/25],Step [3/64],Loss: 0.6176 ,Acc_labels: 38/64 (59%)
# Epoch [4/25],Step [4/64],Loss: 0.5724 ,Acc_labels: 47/64 (73%)
# Epoch [4/25],Step [5/64],Loss: 0.5726 ,Acc_labels: 44/64 (69%)
# Epoch [4/25],Step [6/64],Loss: 0.5291 ,Acc_labels: 45/64 (70%)
# Epoch [4/25],Step [7/64],Loss: 0.5693 ,Acc_labels: 45/64 (70%)
# Epoch [4/25],Step [8/64],Loss: 0.6205 ,Acc_labels: 47/64 (73%)
# Epoch [4/25],Step [9/64],Loss: 0.6409 ,Acc_labels: 39/64 (61%)
# Epoch [4/25],Step [10/64],Loss: 0.8161 ,Acc_labels: 38/64 (59%)
# Epoch [4/25],Step [11/64],Loss: 0.7772 ,Acc_labels: 37/64 (58%)
# Epoch [4/25],Step [12/64],Loss: 0.5880 ,Acc_labels: 43/64 (67%)
# Epoch [4/25],Step [13/64],Loss: 0.6406 ,Acc_labels: 41/64 (64%)
# Epoch [4/25],Step [14/64],Loss: 0.6252 ,Acc_labels: 43/64 (67%)
# Epoch [4/25],Step [15/64],Loss: 0.5910 ,Acc_labels: 44/64 (69%)
# Epoch [4/25],Step [16/40],Loss: 0.6384 ,Acc_labels: 20/40 (50%)
#
#  Time needed to train  0.38257800007704645
#
# Test set: Loss: 0.6398,Acc_labels: 667/1000 67%
# Epoch [5/25],Step [1/64],Loss: 0.6986 ,Acc_labels: 42/64 (66%)
# Epoch [5/25],Step [2/64],Loss: 0.6031 ,Acc_labels: 42/64 (66%)
# Epoch [5/25],Step [3/64],Loss: 0.5378 ,Acc_labels: 45/64 (70%)
# Epoch [5/25],Step [4/64],Loss: 0.5761 ,Acc_labels: 46/64 (72%)
# Epoch [5/25],Step [5/64],Loss: 0.6000 ,Acc_labels: 47/64 (73%)
# Epoch [5/25],Step [6/64],Loss: 0.5421 ,Acc_labels: 44/64 (69%)
# Epoch [5/25],Step [7/64],Loss: 0.6906 ,Acc_labels: 40/64 (62%)
# Epoch [5/25],Step [8/64],Loss: 0.6875 ,Acc_labels: 34/64 (53%)
# Epoch [5/25],Step [9/64],Loss: 0.6178 ,Acc_labels: 37/64 (58%)
# Epoch [5/25],Step [10/64],Loss: 0.5705 ,Acc_labels: 45/64 (70%)
# Epoch [5/25],Step [11/64],Loss: 0.5644 ,Acc_labels: 43/64 (67%)
# Epoch [5/25],Step [12/64],Loss: 0.6232 ,Acc_labels: 40/64 (62%)
# Epoch [5/25],Step [13/64],Loss: 0.5501 ,Acc_labels: 47/64 (73%)
# Epoch [5/25],Step [14/64],Loss: 0.7081 ,Acc_labels: 41/64 (64%)
# Epoch [5/25],Step [15/64],Loss: 0.5236 ,Acc_labels: 49/64 (77%)
# Epoch [5/25],Step [16/40],Loss: 0.6428 ,Acc_labels: 29/40 (72%)
#
#  Time needed to train  0.3747113950084895
#
# Test set: Loss: 0.5665,Acc_labels: 742/1000 74%
# Epoch [6/25],Step [1/64],Loss: 0.6106 ,Acc_labels: 42/64 (66%)
# Epoch [6/25],Step [2/64],Loss: 0.5819 ,Acc_labels: 44/64 (69%)
# Epoch [6/25],Step [3/64],Loss: 0.6122 ,Acc_labels: 42/64 (66%)
# Epoch [6/25],Step [4/64],Loss: 0.5852 ,Acc_labels: 45/64 (70%)
# Epoch [6/25],Step [5/64],Loss: 0.5929 ,Acc_labels: 41/64 (64%)
# Epoch [6/25],Step [6/64],Loss: 0.5734 ,Acc_labels: 46/64 (72%)
# Epoch [6/25],Step [7/64],Loss: 0.4605 ,Acc_labels: 51/64 (80%)
# Epoch [6/25],Step [8/64],Loss: 0.7322 ,Acc_labels: 37/64 (58%)
# Epoch [6/25],Step [9/64],Loss: 0.5247 ,Acc_labels: 51/64 (80%)
# Epoch [6/25],Step [10/64],Loss: 0.6240 ,Acc_labels: 40/64 (62%)
# Epoch [6/25],Step [11/64],Loss: 0.5607 ,Acc_labels: 45/64 (70%)
# Epoch [6/25],Step [12/64],Loss: 0.5877 ,Acc_labels: 44/64 (69%)
# Epoch [6/25],Step [13/64],Loss: 0.5315 ,Acc_labels: 44/64 (69%)
# Epoch [6/25],Step [14/64],Loss: 0.4619 ,Acc_labels: 51/64 (80%)
# Epoch [6/25],Step [15/64],Loss: 0.4986 ,Acc_labels: 50/64 (78%)
# Epoch [6/25],Step [16/40],Loss: 0.4724 ,Acc_labels: 30/40 (75%)
#
#  Time needed to train  0.42929555592127144
#
# Test set: Loss: 0.5251,Acc_labels: 755/1000 76%
# Epoch [7/25],Step [1/64],Loss: 0.5518 ,Acc_labels: 45/64 (70%)
# Epoch [7/25],Step [2/64],Loss: 0.4098 ,Acc_labels: 54/64 (84%)
# Epoch [7/25],Step [3/64],Loss: 0.5299 ,Acc_labels: 47/64 (73%)
# Epoch [7/25],Step [4/64],Loss: 0.4651 ,Acc_labels: 48/64 (75%)
# Epoch [7/25],Step [5/64],Loss: 0.5578 ,Acc_labels: 45/64 (70%)
# Epoch [7/25],Step [6/64],Loss: 0.5435 ,Acc_labels: 45/64 (70%)
# Epoch [7/25],Step [7/64],Loss: 0.5239 ,Acc_labels: 48/64 (75%)
# Epoch [7/25],Step [8/64],Loss: 0.6113 ,Acc_labels: 43/64 (67%)
# Epoch [7/25],Step [9/64],Loss: 0.4732 ,Acc_labels: 50/64 (78%)
# Epoch [7/25],Step [10/64],Loss: 0.4608 ,Acc_labels: 51/64 (80%)
# Epoch [7/25],Step [11/64],Loss: 0.5097 ,Acc_labels: 46/64 (72%)
# Epoch [7/25],Step [12/64],Loss: 0.6228 ,Acc_labels: 45/64 (70%)
# Epoch [7/25],Step [13/64],Loss: 0.5483 ,Acc_labels: 47/64 (73%)
# Epoch [7/25],Step [14/64],Loss: 0.4998 ,Acc_labels: 46/64 (72%)
# Epoch [7/25],Step [15/64],Loss: 0.5975 ,Acc_labels: 41/64 (64%)
# Epoch [7/25],Step [16/40],Loss: 0.6804 ,Acc_labels: 25/40 (62%)
#
#  Time needed to train  0.378565834951587
#
# Test set: Loss: 0.5460,Acc_labels: 721/1000 72%
# Epoch [8/25],Step [1/64],Loss: 0.4814 ,Acc_labels: 49/64 (77%)
# Epoch [8/25],Step [2/64],Loss: 0.5180 ,Acc_labels: 52/64 (81%)
# Epoch [8/25],Step [3/64],Loss: 0.4855 ,Acc_labels: 49/64 (77%)
# Epoch [8/25],Step [4/64],Loss: 0.5010 ,Acc_labels: 48/64 (75%)
# Epoch [8/25],Step [5/64],Loss: 0.6077 ,Acc_labels: 46/64 (72%)
# Epoch [8/25],Step [6/64],Loss: 0.5803 ,Acc_labels: 45/64 (70%)
# Epoch [8/25],Step [7/64],Loss: 0.5942 ,Acc_labels: 41/64 (64%)
# Epoch [8/25],Step [8/64],Loss: 0.5051 ,Acc_labels: 45/64 (70%)
# Epoch [8/25],Step [9/64],Loss: 0.4924 ,Acc_labels: 48/64 (75%)
# Epoch [8/25],Step [10/64],Loss: 0.4699 ,Acc_labels: 52/64 (81%)
# Epoch [8/25],Step [11/64],Loss: 0.5673 ,Acc_labels: 44/64 (69%)
# Epoch [8/25],Step [12/64],Loss: 0.4490 ,Acc_labels: 50/64 (78%)
# Epoch [8/25],Step [13/64],Loss: 0.5650 ,Acc_labels: 46/64 (72%)
# Epoch [8/25],Step [14/64],Loss: 0.6404 ,Acc_labels: 42/64 (66%)
# Epoch [8/25],Step [15/64],Loss: 0.5191 ,Acc_labels: 48/64 (75%)
# Epoch [8/25],Step [16/40],Loss: 0.5463 ,Acc_labels: 27/40 (68%)
#
#  Time needed to train  0.403323782957159
#
# Test set: Loss: 0.5148,Acc_labels: 768/1000 77%
# Epoch [9/25],Step [1/64],Loss: 0.4176 ,Acc_labels: 49/64 (77%)
# Epoch [9/25],Step [2/64],Loss: 0.5057 ,Acc_labels: 48/64 (75%)
# Epoch [9/25],Step [3/64],Loss: 0.4433 ,Acc_labels: 55/64 (86%)
# Epoch [9/25],Step [4/64],Loss: 0.4382 ,Acc_labels: 53/64 (83%)
# Epoch [9/25],Step [5/64],Loss: 0.4946 ,Acc_labels: 48/64 (75%)
# Epoch [9/25],Step [6/64],Loss: 0.4384 ,Acc_labels: 52/64 (81%)
# Epoch [9/25],Step [7/64],Loss: 0.3010 ,Acc_labels: 57/64 (89%)
# Epoch [9/25],Step [8/64],Loss: 0.5560 ,Acc_labels: 48/64 (75%)
# Epoch [9/25],Step [9/64],Loss: 0.6392 ,Acc_labels: 44/64 (69%)
# Epoch [9/25],Step [10/64],Loss: 0.4614 ,Acc_labels: 50/64 (78%)
# Epoch [9/25],Step [11/64],Loss: 0.5734 ,Acc_labels: 45/64 (70%)
# Epoch [9/25],Step [12/64],Loss: 0.5327 ,Acc_labels: 44/64 (69%)
# Epoch [9/25],Step [13/64],Loss: 0.5446 ,Acc_labels: 43/64 (67%)
# Epoch [9/25],Step [14/64],Loss: 0.5813 ,Acc_labels: 45/64 (70%)
# Epoch [9/25],Step [15/64],Loss: 0.5325 ,Acc_labels: 45/64 (70%)
# ...
# Epoch [14/25],Step [7/64],Loss: 0.2402 ,Acc_labels: 59/64 (92%)
# Epoch [14/25],Step [8/64],Loss: 0.4247 ,Acc_labels: 51/64 (80%)
# Epoch [14/25],Step [9/64],Loss: 0.4324 ,Acc_labels: 51/64 (80%)
# Epoch [14/25],Step [10/64],Loss: 0.3269 ,Acc_labels: 56/64 (88%)
# Epoch [14/25],Step [11/64],Loss: 0.4013 ,Acc_labels: 52/64 (81%)
# Epoch [14/25],Step [12/64],Loss: 0.4117 ,Acc_labels: 54/64 (84%)
# Epoch [14/25],Step [13/64],Loss: 0.4957 ,Acc_labels: 48/64 (75%)
# Epoch [14/25],Step [14/64],Loss: 0.3816 ,Acc_labels: 52/64 (81%)
# Epoch [14/25],Step [15/64],Loss: 0.4566 ,Acc_labels: 52/64 (81%)
# Epoch [14/25],Step [16/40],Loss: 0.4249 ,Acc_labels: 32/40 (80%)
#
#  Time needed to train  0.36584200290963054
#
# Test set: Loss: 0.5310,Acc_labels: 753/1000 75%
# Epoch [15/25],Step [1/64],Loss: 0.3479 ,Acc_labels: 56/64 (88%)
# Epoch [15/25],Step [2/64],Loss: 0.2461 ,Acc_labels: 58/64 (91%)
# Epoch [15/25],Step [3/64],Loss: 0.5176 ,Acc_labels: 49/64 (77%)
# Epoch [15/25],Step [4/64],Loss: 0.3520 ,Acc_labels: 53/64 (83%)
# Epoch [15/25],Step [5/64],Loss: 0.4231 ,Acc_labels: 52/64 (81%)
# Epoch [15/25],Step [6/64],Loss: 0.4114 ,Acc_labels: 54/64 (84%)
# Epoch [15/25],Step [7/64],Loss: 0.4289 ,Acc_labels: 50/64 (78%)
# Epoch [15/25],Step [8/64],Loss: 0.2865 ,Acc_labels: 58/64 (91%)
# Epoch [15/25],Step [9/64],Loss: 0.3099 ,Acc_labels: 57/64 (89%)
# Epoch [15/25],Step [10/64],Loss: 0.3998 ,Acc_labels: 55/64 (86%)
# Epoch [15/25],Step [11/64],Loss: 0.3554 ,Acc_labels: 55/64 (86%)
# Epoch [15/25],Step [12/64],Loss: 0.3901 ,Acc_labels: 53/64 (83%)
# Epoch [15/25],Step [13/64],Loss: 0.4686 ,Acc_labels: 49/64 (77%)
# Epoch [15/25],Step [14/64],Loss: 0.3332 ,Acc_labels: 53/64 (83%)
# Epoch [15/25],Step [15/64],Loss: 0.5036 ,Acc_labels: 46/64 (72%)
# Epoch [15/25],Step [16/40],Loss: 0.4592 ,Acc_labels: 29/40 (72%)
#
#  Time needed to train  0.37580615596380085
#
# Test set: Loss: 0.5214,Acc_labels: 752/1000 75%
# Epoch [16/25],Step [1/64],Loss: 0.3237 ,Acc_labels: 55/64 (86%)
# Epoch [16/25],Step [2/64],Loss: 0.3175 ,Acc_labels: 54/64 (84%)
# Epoch [16/25],Step [3/64],Loss: 0.5292 ,Acc_labels: 50/64 (78%)
# Epoch [16/25],Step [4/64],Loss: 0.3747 ,Acc_labels: 52/64 (81%)
# Epoch [16/25],Step [5/64],Loss: 0.3546 ,Acc_labels: 53/64 (83%)
# Epoch [16/25],Step [6/64],Loss: 0.3156 ,Acc_labels: 58/64 (91%)
# Epoch [16/25],Step [7/64],Loss: 0.5014 ,Acc_labels: 48/64 (75%)
# Epoch [16/25],Step [8/64],Loss: 0.3617 ,Acc_labels: 52/64 (81%)
# Epoch [16/25],Step [9/64],Loss: 0.3519 ,Acc_labels: 51/64 (80%)
# Epoch [16/25],Step [10/64],Loss: 0.3445 ,Acc_labels: 56/64 (88%)
# Epoch [16/25],Step [11/64],Loss: 0.3470 ,Acc_labels: 54/64 (84%)
# Epoch [16/25],Step [12/64],Loss: 0.2576 ,Acc_labels: 59/64 (92%)
# Epoch [16/25],Step [13/64],Loss: 0.3564 ,Acc_labels: 52/64 (81%)
# Epoch [16/25],Step [14/64],Loss: 0.3877 ,Acc_labels: 54/64 (84%)
# Epoch [16/25],Step [15/64],Loss: 0.3134 ,Acc_labels: 54/64 (84%)
# Epoch [16/25],Step [16/40],Loss: 0.4088 ,Acc_labels: 32/40 (80%)
#
#  Time needed to train  0.3672634899849072
# Test set: Loss: 0.6803,Acc_labels: 736/1000 74%
# Epoch [17/25],Step [1/64],Loss: 0.4681 ,Acc_labels: 49/64 (77%)
# Epoch [17/25],Step [2/64],Loss: 0.3442 ,Acc_labels: 56/64 (88%)
# Epoch [17/25],Step [3/64],Loss: 0.4175 ,Acc_labels: 51/64 (80%)
# Epoch [17/25],Step [4/64],Loss: 0.3896 ,Acc_labels: 55/64 (86%)
# Epoch [17/25],Step [5/64],Loss: 0.4486 ,Acc_labels: 48/64 (75%)
# Epoch [17/25],Step [6/64],Loss: 0.3602 ,Acc_labels: 53/64 (83%)
# Epoch [17/25],Step [7/64],Loss: 0.2930 ,Acc_labels: 56/64 (88%)
# Epoch [17/25],Step [8/64],Loss: 0.5836 ,Acc_labels: 46/64 (72%)
# Epoch [17/25],Step [9/64],Loss: 0.3845 ,Acc_labels: 50/64 (78%)
# Epoch [17/25],Step [10/64],Loss: 0.5291 ,Acc_labels: 49/64 (77%)
# Epoch [17/25],Step [11/64],Loss: 0.3891 ,Acc_labels: 53/64 (83%)
# Epoch [17/25],Step [12/64],Loss: 0.3019 ,Acc_labels: 58/64 (91%)
# Epoch [17/25],Step [13/64],Loss: 0.5202 ,Acc_labels: 48/64 (75%)
# Epoch [17/25],Step [14/64],Loss: 0.3361 ,Acc_labels: 55/64 (86%)
# Epoch [17/25],Step [15/64],Loss: 0.3729 ,Acc_labels: 51/64 (80%)
# Epoch [17/25],Step [16/40],Loss: 0.4904 ,Acc_labels: 31/40 (78%)
#
#  Time needed to train  0.42925976996775717
#
# Test set: Loss: 0.5397,Acc_labels: 757/1000 76%
# Epoch [18/25],Step [1/64],Loss: 0.2888 ,Acc_labels: 55/64 (86%)
# Epoch [18/25],Step [2/64],Loss: 0.3768 ,Acc_labels: 51/64 (80%)
# Epoch [18/25],Step [3/64],Loss: 0.2918 ,Acc_labels: 55/64 (86%)
# Epoch [18/25],Step [4/64],Loss: 0.2859 ,Acc_labels: 57/64 (89%)
# Epoch [18/25],Step [5/64],Loss: 0.4184 ,Acc_labels: 52/64 (81%)
# Epoch [18/25],Step [6/64],Loss: 0.2806 ,Acc_labels: 58/64 (91%)
# Epoch [18/25],Step [7/64],Loss: 0.3151 ,Acc_labels: 52/64 (81%)
# Epoch [18/25],Step [8/64],Loss: 0.2570 ,Acc_labels: 58/64 (91%)
# Epoch [18/25],Step [9/64],Loss: 0.3433 ,Acc_labels: 53/64 (83%)
# Epoch [18/25],Step [10/64],Loss: 0.4298 ,Acc_labels: 50/64 (78%)
# Epoch [18/25],Step [11/64],Loss: 0.2753 ,Acc_labels: 58/64 (91%)
# Epoch [18/25],Step [12/64],Loss: 0.3478 ,Acc_labels: 55/64 (86%)
# Epoch [18/25],Step [13/64],Loss: 0.3442 ,Acc_labels: 54/64 (84%)
# Epoch [18/25],Step [14/64],Loss: 0.3680 ,Acc_labels: 50/64 (78%)
# Epoch [18/25],Step [15/64],Loss: 0.3252 ,Acc_labels: 54/64 (84%)
# Epoch [18/25],Step [16/40],Loss: 0.2371 ,Acc_labels: 39/40 (98%)
#
#  Time needed to train  0.37791851989459246
#
# Test set: Loss: 0.5333,Acc_labels: 755/1000 76%
# Epoch [19/25],Step [1/64],Loss: 0.3066 ,Acc_labels: 55/64 (86%)
# Epoch [19/25],Step [2/64],Loss: 0.2296 ,Acc_labels: 58/64 (91%)
# Epoch [19/25],Step [3/64],Loss: 0.3565 ,Acc_labels: 56/64 (88%)
# Epoch [19/25],Step [4/64],Loss: 0.2717 ,Acc_labels: 57/64 (89%)
# Epoch [19/25],Step [5/64],Loss: 0.3742 ,Acc_labels: 55/64 (86%)
# Epoch [19/25],Step [6/64],Loss: 0.2435 ,Acc_labels: 57/64 (89%)
# Epoch [19/25],Step [7/64],Loss: 0.2835 ,Acc_labels: 57/64 (89%)
# Epoch [19/25],Step [8/64],Loss: 0.1994 ,Acc_labels: 61/64 (95%)
# Epoch [19/25],Step [9/64],Loss: 0.3125 ,Acc_labels: 54/64 (84%)
# Epoch [19/25],Step [10/64],Loss: 0.2928 ,Acc_labels: 54/64 (84%)
# Epoch [19/25],Step [11/64],Loss: 0.2973 ,Acc_labels: 55/64 (86%)
# Epoch [19/25],Step [12/64],Loss: 0.3392 ,Acc_labels: 55/64 (86%)
# Epoch [19/25],Step [13/64],Loss: 0.4182 ,Acc_labels: 50/64 (78%)
# Epoch [19/25],Step [14/64],Loss: 0.2493 ,Acc_labels: 58/64 (91%)
# Epoch [19/25],Step [15/64],Loss: 0.2391 ,Acc_labels: 57/64 (89%)
# Epoch [19/25],Step [16/40],Loss: 0.2344 ,Acc_labels: 34/40 (85%)
#
#  Time needed to train  0.37109849508851767
#
# Test set: Loss: 0.6313,Acc_labels: 746/1000 75%
# Epoch [20/25],Step [1/64],Loss: 0.2087 ,Acc_labels: 58/64 (91%)
# Epoch [20/25],Step [2/64],Loss: 0.3742 ,Acc_labels: 55/64 (86%)
# Epoch [20/25],Step [3/64],Loss: 0.2699 ,Acc_labels: 59/64 (92%)
# Epoch [20/25],Step [4/64],Loss: 0.3069 ,Acc_labels: 53/64 (83%)
# Epoch [20/25],Step [5/64],Loss: 0.4118 ,Acc_labels: 55/64 (86%)
# Epoch [20/25],Step [6/64],Loss: 0.3146 ,Acc_labels: 54/64 (84%)
# Epoch [20/25],Step [7/64],Loss: 0.3615 ,Acc_labels: 57/64 (89%)
# Epoch [20/25],Step [8/64],Loss: 0.3203 ,Acc_labels: 54/64 (84%)
# Epoch [20/25],Step [9/64],Loss: 0.2994 ,Acc_labels: 59/64 (92%)
# Epoch [20/25],Step [10/64],Loss: 0.4981 ,Acc_labels: 50/64 (78%)
# Epoch [20/25],Step [11/64],Loss: 0.3203 ,Acc_labels: 54/64 (84%)
# Epoch [20/25],Step [12/64],Loss: 0.2520 ,Acc_labels: 60/64 (94%)
# Epoch [20/25],Step [13/64],Loss: 0.3294 ,Acc_labels: 54/64 (84%)
# Epoch [20/25],Step [14/64],Loss: 0.3748 ,Acc_labels: 49/64 (77%)
# Epoch [20/25],Step [15/64],Loss: 0.3173 ,Acc_labels: 57/64 (89%)
# Epoch [20/25],Step [16/40],Loss: 0.2668 ,Acc_labels: 36/40 (90%)
#
#  Time needed to train  0.3722833120264113
#
# Test set: Loss: 0.5616,Acc_labels: 752/1000 75%
# Epoch [21/25],Step [1/64],Loss: 0.2197 ,Acc_labels: 58/64 (91%)
# Epoch [21/25],Step [2/64],Loss: 0.2431 ,Acc_labels: 58/64 (91%)
# Epoch [21/25],Step [3/64],Loss: 0.2837 ,Acc_labels: 56/64 (88%)
# Epoch [21/25],Step [4/64],Loss: 0.2530 ,Acc_labels: 56/64 (88%)
# Epoch [21/25],Step [5/64],Loss: 0.2229 ,Acc_labels: 59/64 (92%)
# Epoch [21/25],Step [6/64],Loss: 0.2172 ,Acc_labels: 59/64 (92%)
# Epoch [21/25],Step [7/64],Loss: 0.2656 ,Acc_labels: 59/64 (92%)
# Epoch [21/25],Step [8/64],Loss: 0.1812 ,Acc_labels: 59/64 (92%)
# Epoch [21/25],Step [9/64],Loss: 0.5078 ,Acc_labels: 48/64 (75%)
# Epoch [21/25],Step [10/64],Loss: 0.3293 ,Acc_labels: 54/64 (84%)
# Epoch [21/25],Step [11/64],Loss: 0.3358 ,Acc_labels: 56/64 (88%)
# Epoch [21/25],Step [12/64],Loss: 0.2359 ,Acc_labels: 59/64 (92%)
# Epoch [21/25],Step [13/64],Loss: 0.3597 ,Acc_labels: 52/64 (81%)
# Epoch [21/25],Step [14/64],Loss: 0.3245 ,Acc_labels: 54/64 (84%)
# Epoch [21/25],Step [15/64],Loss: 0.3793 ,Acc_labels: 56/64 (88%)
# Epoch [21/25],Step [16/40],Loss: 0.4297 ,Acc_labels: 31/40 (78%)
#
#  Time needed to train  0.37216267501935363
#
# Test set: Loss: 0.5418,Acc_labels: 745/1000 74%
# Epoch [22/25],Step [1/64],Loss: 0.2811 ,Acc_labels: 55/64 (86%)
# Epoch [22/25],Step [2/64],Loss: 0.2010 ,Acc_labels: 58/64 (91%)
# Epoch [22/25],Step [3/64],Loss: 0.2370 ,Acc_labels: 57/64 (89%)
# Epoch [22/25],Step [4/64],Loss: 0.3243 ,Acc_labels: 53/64 (83%)
# Epoch [22/25],Step [5/64],Loss: 0.2618 ,Acc_labels: 58/64 (91%)
# Epoch [22/25],Step [6/64],Loss: 0.2969 ,Acc_labels: 54/64 (84%)
# Epoch [22/25],Step [7/64],Loss: 0.3062 ,Acc_labels: 53/64 (83%)
# Epoch [22/25],Step [8/64],Loss: 0.1724 ,Acc_labels: 61/64 (95%)
# Epoch [22/25],Step [9/64],Loss: 0.2506 ,Acc_labels: 56/64 (88%)
# Epoch [22/25],Step [10/64],Loss: 0.2007 ,Acc_labels: 60/64 (94%)
# Epoch [22/25],Step [11/64],Loss: 0.3855 ,Acc_labels: 53/64 (83%)
# Epoch [22/25],Step [12/64],Loss: 0.2492 ,Acc_labels: 56/64 (88%)
# Epoch [22/25],Step [13/64],Loss: 0.2147 ,Acc_labels: 59/64 (92%)
# Epoch [22/25],Step [14/64],Loss: 0.2577 ,Acc_labels: 58/64 (91%)
# Epoch [22/25],Step [15/64],Loss: 0.2654 ,Acc_labels: 57/64 (89%)
# Epoch [22/25],Step [16/40],Loss: 0.3598 ,Acc_labels: 32/40 (80%)
#
#  Time needed to train  0.43714674399234354
#
# Test set: Loss: 0.5747,Acc_labels: 764/1000 76%
# Epoch [23/25],Step [1/64],Loss: 0.2606 ,Acc_labels: 58/64 (91%)
# Epoch [23/25],Step [2/64],Loss: 0.1763 ,Acc_labels: 61/64 (95%)
# Epoch [23/25],Step [3/64],Loss: 0.2112 ,Acc_labels: 57/64 (89%)
# Epoch [23/25],Step [4/64],Loss: 0.2264 ,Acc_labels: 57/64 (89%)
# Epoch [23/25],Step [5/64],Loss: 0.1960 ,Acc_labels: 58/64 (91%)
# Epoch [23/25],Step [6/64],Loss: 0.2013 ,Acc_labels: 59/64 (92%)
# Epoch [23/25],Step [7/64],Loss: 0.3272 ,Acc_labels: 55/64 (86%)
# Epoch [23/25],Step [8/64],Loss: 0.2063 ,Acc_labels: 56/64 (88%)
# Epoch [23/25],Step [9/64],Loss: 0.1973 ,Acc_labels: 58/64 (91%)
# Epoch [23/25],Step [10/64],Loss: 0.2359 ,Acc_labels: 60/64 (94%)
# Epoch [23/25],Step [11/64],Loss: 0.1921 ,Acc_labels: 59/64 (92%)
# Epoch [23/25],Step [12/64],Loss: 0.2607 ,Acc_labels: 56/64 (88%)
# Epoch [23/25],Step [13/64],Loss: 0.2972 ,Acc_labels: 56/64 (88%)
# Epoch [23/25],Step [14/64],Loss: 0.2752 ,Acc_labels: 54/64 (84%)
# Epoch [23/25],Step [15/64],Loss: 0.3119 ,Acc_labels: 52/64 (81%)
# Epoch [23/25],Step [16/40],Loss: 0.2642 ,Acc_labels: 35/40 (88%)
#
#  Time needed to train  0.42287059302907437
#
# Test set: Loss: 0.6117,Acc_labels: 768/1000 77%
# Epoch [24/25],Step [1/64],Loss: 0.2727 ,Acc_labels: 61/64 (95%)
# Epoch [24/25],Step [2/64],Loss: 0.2348 ,Acc_labels: 58/64 (91%)
# Epoch [24/25],Step [3/64],Loss: 0.3907 ,Acc_labels: 49/64 (77%)
# Epoch [24/25],Step [4/64],Loss: 0.2411 ,Acc_labels: 57/64 (89%)
# Epoch [24/25],Step [5/64],Loss: 0.2432 ,Acc_labels: 56/64 (88%)
# Epoch [24/25],Step [6/64],Loss: 0.1858 ,Acc_labels: 58/64 (91%)
# Epoch [24/25],Step [7/64],Loss: 0.2280 ,Acc_labels: 59/64 (92%)
# Epoch [24/25],Step [8/64],Loss: 0.3020 ,Acc_labels: 57/64 (89%)
# Epoch [24/25],Step [9/64],Loss: 0.2583 ,Acc_labels: 57/64 (89%)
# Epoch [24/25],Step [10/64],Loss: 0.2214 ,Acc_labels: 58/64 (91%)
# Epoch [24/25],Step [11/64],Loss: 0.2326 ,Acc_labels: 61/64 (95%)
# Epoch [24/25],Step [12/64],Loss: 0.2162 ,Acc_labels: 59/64 (92%)
# Epoch [24/25],Step [13/64],Loss: 0.3672 ,Acc_labels: 51/64 (80%)
# Epoch [24/25],Step [14/64],Loss: 0.3010 ,Acc_labels: 54/64 (84%)
# Epoch [24/25],Step [15/64],Loss: 0.2223 ,Acc_labels: 60/64 (94%)
# Epoch [24/25],Step [16/40],Loss: 0.1946 ,Acc_labels: 37/40 (92%)
#
#  Time needed to train  0.3697493929648772
#
# Test set: Loss: 0.5548,Acc_labels: 758/1000 76%
# Epoch [25/25],Step [1/64],Loss: 0.2037 ,Acc_labels: 59/64 (92%)
# Epoch [25/25],Step [2/64],Loss: 0.2813 ,Acc_labels: 57/64 (89%)
# Epoch [25/25],Step [3/64],Loss: 0.1467 ,Acc_labels: 61/64 (95%)
# Epoch [25/25],Step [4/64],Loss: 0.2375 ,Acc_labels: 58/64 (91%)
# Epoch [25/25],Step [5/64],Loss: 0.1803 ,Acc_labels: 59/64 (92%)
# Epoch [25/25],Step [6/64],Loss: 0.2020 ,Acc_labels: 59/64 (92%)
# Epoch [25/25],Step [7/64],Loss: 0.1991 ,Acc_labels: 59/64 (92%)
# Epoch [25/25],Step [8/64],Loss: 0.2921 ,Acc_labels: 54/64 (84%)
# Epoch [25/25],Step [9/64],Loss: 0.1929 ,Acc_labels: 61/64 (95%)
# Epoch [25/25],Step [10/64],Loss: 0.2490 ,Acc_labels: 56/64 (88%)
# Epoch [25/25],Step [11/64],Loss: 0.1324 ,Acc_labels: 60/64 (94%)
# Epoch [25/25],Step [12/64],Loss: 0.1672 ,Acc_labels: 61/64 (95%)
# Epoch [25/25],Step [13/64],Loss: 0.1839 ,Acc_labels: 59/64 (92%)
# Epoch [25/25],Step [14/64],Loss: 0.2166 ,Acc_labels: 58/64 (91%)
# Epoch [25/25],Step [15/64],Loss: 0.2669 ,Acc_labels: 58/64 (91%)
# Epoch [25/25],Step [16/40],Loss: 0.3352 ,Acc_labels: 35/40 (88%)
#
#  Time needed to train  0.4705708170076832
#
# Test set: Loss: 0.5833,Acc_labels: 759/1000 76%
# Epoch [26/25],Step [1/64],Loss: 0.2362 ,Acc_labels: 58/64 (91%)
# Epoch [26/25],Step [2/64],Loss: 0.2183 ,Acc_labels: 56/64 (88%)
# Epoch [26/25],Step [3/64],Loss: 0.2552 ,Acc_labels: 58/64 (91%)
# Epoch [26/25],Step [4/64],Loss: 0.1567 ,Acc_labels: 61/64 (95%)
# Epoch [26/25],Step [5/64],Loss: 0.2101 ,Acc_labels: 57/64 (89%)
# Epoch [26/25],Step [6/64],Loss: 0.1779 ,Acc_labels: 61/64 (95%)
# Epoch [26/25],Step [7/64],Loss: 0.1900 ,Acc_labels: 59/64 (92%)
# Epoch [26/25],Step [8/64],Loss: 0.1441 ,Acc_labels: 61/64 (95%)
# Epoch [26/25],Step [9/64],Loss: 0.2902 ,Acc_labels: 55/64 (86%)
# Epoch [26/25],Step [10/64],Loss: 0.2864 ,Acc_labels: 59/64 (92%)
# Epoch [26/25],Step [11/64],Loss: 0.1923 ,Acc_labels: 61/64 (95%)
# Epoch [26/25],Step [12/64],Loss: 0.1658 ,Acc_labels: 60/64 (94%)
# Epoch [26/25],Step [13/64],Loss: 0.2603 ,Acc_labels: 54/64 (84%)
# Epoch [26/25],Step [14/64],Loss: 0.2008 ,Acc_labels: 58/64 (91%)
# Epoch [26/25],Step [15/64],Loss: 0.3147 ,Acc_labels: 59/64 (92%)
# Epoch [26/25],Step [16/40],Loss: 0.2256 ,Acc_labels: 35/40 (88%)
#
#  Time needed to train  0.4185040759621188
#
# Test set: Loss: 0.5990,Acc_labels: 765/1000 76%
#
#  ************************ Statistics of Network 2 ************************
#
#
#  Average time needed for training:  0.2475617467937991
#
#  Training:
#  Average accuracy of labels: 65.1796875
#  Median accuracy of labels: 66.40625
#  Average accuracy on labels: 65.1796875
#  Maximum accuracy on labels: 85.9375
#  Minimum accuracy on labels: 43.75
#  Spread of accuracy on labels: 8.526730869045098
#  Average accuracy of digits: 43.97578125
#  Median accuracy of digits: 47.578125
#  Average accuracy on digits: 43.97578125
#  Maximum accuracy on digits: 76.25
#  Minimum accuracy on digits: 7.8125
#  Spread of accuracy on digits: 15.144387810589846
#
#  Testing:
#  Average accuracy of labels: 69.028
#  Median accuracy of labels: 70.7
#  Average accuracy on labels: 69.028
#  Maximum accuracy on labels: 76.8
#  Minimum accuracy on labels: 56.1
#  Spread of accuracy on labels: 6.471831270977326
#  Average accuracy of digits: 66.416
#  Median accuracy of digits: 75.3
#  Average accuracy on digits: 66.416
#  Maximum accuracy on digits: 87.5
#  Minimum accuracy on digits: 26.4
#  Spread of accuracy on digits: 20.432310605182828
#
#  ************************ Statistics of Network 1 ************************
#
#
#  Average time needed for training  0.3926992114726454
#
#  Training:
#  Average accuracy of labels: 73.57317708333333
#  Median accuracy of labels: 74.8046875
#  Average accuracy on labels: 73.57317708333333
#  Maximum accuracy on labels: 91.30859375
#  Minimum accuracy on labels: 54.1015625
#  Spread of accuracy on labels: 9.534297900427037
#
#  Testing:
#  Average accuracy of labels: 74.08
#  Median accuracy of labels: 75.5
#  Average accuracy on labels: 74.08
#  Maximum accuracy on labels: 77.6
#  Minimum accuracy on labels: 56.0
#  Spread of accuracy on labels: 4.467475051226737

# %%
print(" \n ************************ Statistics of Network 2 ************************ \n")
print("\n Average time needed for training: ", avg_time2)
print("\n Training: ","\n Average accuracy of labels: {}".format(st.mean(train_acc_classes__)),"\n Median accuracy of labels: {}".format(st.median(train_acc_classes__)),"\n Average accuracy on labels: {}".format(st.mean(train_acc_classes__)),"\n Maximum accuracy on labels: {}".format(max(train_acc_classes__)),"\n Minimum accuracy on labels: {}".format(min(train_acc_classes__)),"\n Spread of accuracy on labels: {}".format(st.stdev(train_acc_classes__)),"\n Average accuracy of digits: {}".format(st.mean(train_acc_digits__)),"\n Median accuracy of digits: {}".format(st.median(train_acc_digits__)),"\n Average accuracy on digits: {}".format(st.mean(train_acc_digits__)),"\n Maximum accuracy on digits: {}".format(max(train_acc_digits__)),"\n Minimum accuracy on digits: {}".format(min(train_acc_digits__)),"\n Spread of accuracy on digits: {}".format(st.stdev(train_acc_digits__)))
print("\n Testing: ","\n Average accuracy of labels: {}".format(st.mean(test_acc_classes__)),"\n Median accuracy of labels: {}".format(st.median(test_acc_classes__)),"\n Average accuracy on labels: {}".format(st.mean(test_acc_classes__)),"\n Maximum accuracy on labels: {}".format(max(test_acc_classes__)),"\n Minimum accuracy on labels: {}".format(min(test_acc_classes__)),"\n Spread of accuracy on labels: {}".format(st.stdev(test_acc_classes__)),"\n Average accuracy of digits: {}".format(st.mean(test_acc_digits__)),"\n Median accuracy of digits: {}".format(st.median(test_acc_digits__)),"\n Average accuracy on digits: {}".format(st.mean(test_acc_digits__)),"\n Maximum accuracy on digits: {}".format(max(test_acc_digits__)),"\n Minimum accuracy on digits: {}".format(min(test_acc_digits__)),"\n Spread of accuracy on digits: {}".format(st.stdev(test_acc_digits__)))
    
    
print("\n ************************ Statistics of Network 1 ************************ \n")
print("\n Average time needed for training ", avg_time1)
print("\n Training: ", "\n Average accuracy of labels: {}".format(st.mean(train_acc__)),"\n Median accuracy of labels: {}".format(st.median(train_acc__)),"\n Average accuracy on labels: {}".format(st.mean(train_acc__)),"\n Maximum accuracy on labels: {}".format(max(train_acc__)),"\n Minimum accuracy on labels: {}".format(min(train_acc__)),"\n Spread of accuracy on labels: {}".format(st.stdev(train_acc__)))
print("\n Testing: ", "\n Average accuracy of labels: {}".format(st.mean(test_acc__)),"\n Median accuracy of labels: {}".format(st.median(test_acc__)), "\n Average accuracy on labels: {}".format(st.mean(test_acc__)),"\n Maximum accuracy on labels: {}".format(max(test_acc__)), "\n Minimum accuracy on labels: {}".format(min(test_acc__)), "\n Spread of accuracy on labels: {}".format(st.stdev(test_acc__)))
